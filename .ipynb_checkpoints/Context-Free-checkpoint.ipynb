# %%
https://github.com/MtnViewJohn/context-free/wiki
http://shiffman.net/a2z/cfg/

# %%
from PIL import Image
view = Image.open("context-free/output/mtree2a.png")
view.size
# Out:
# (640, 640)

# %%
# !ls context-free/input
# Out:
# 1128211071.cfdg			 lesson2_v2.cfdg
# 1128941024.cfdg			 lesson.cfdg
# 1130225163.cfdg			 lesson_v2.cfdg
# 1145254241.cfdg			 line_ending_test_cr.cfdg
# 44402-GGI-helixnebula.cfdg	 line_ending_test_crlf.cfdg
# Agglomeration_3200_2400.cfdg	 line_ending_test_lf.cfdg
# AlfredoArellano1.cfdg		 line_ending_test_multi.cfdg
# AlfredoArellano2.cfdg		 Moire Swirls 2.cfdg
# AlfredoArellano.cfdg		 mtree.cfdg
# algea.cfdg			 mtree-j.cfdg
# aliastest.cfdg			 mtree_v2.cfdg
# alphabet.cfdg			 multiverse.cfdg
# anchient-map.cfdg		 Nebula.cfdg
# ANCIENTMAP2.cfdg		 octopi.cfdg
# ancient-scripts.cfdg		 octopi_v2.cfdg
# attractor.cfdg			 orb_wave.cfdg
# Axl Arias 2.cfdg		 painting1.cfdg
# Barycentric.cfdg		 PIUMA.cfdg
# Bifurcation.cfdg		 Plagium.cfdg
# bleak.cfdg			 point.cfdg
# Bubbles.cfdg			 quadcity.cfdg
# chanukah.cfdg			 quadcity_v2.cfdg
# cilia.cfdg			 Recursive_Rug.cfdg
# ciliasun.cfdg			 rendering-tests.cfdg
# ciliasun_v2.cfdg		 robotgraffititumor.cfdg
# Clifford_Attractors.cfdg	 rose.cfdg
# clouds.cfdg			 rose_v2.cfdg
# confined.cfdg			 seasons.cfdg
# conspiracy1.cfdg		 sierpinski.cfdg
# crystals.cfdg			 sierpinski_v2.cfdg
# cubefield.cfdg			 snowflake.cfdg
# davinciscrapbook.cfdg		 snowflake_v2.cfdg
# demo1.cfdg			 SnowStory.cfdg
# demo1_v2.cfdg			 softcore2.cfdg
# demo2.cfdg			 softercore.cfdg
# demo2_v2.cfdg			 squares.cfdg
# Document11.cfdg			 stairway_II.cfdg
# Estrelles.cfdg			 string-theory.cfdg
# exper-clouds.cfdg		 Symbiosis.cfdg
# experiment000a.cfdg		 tangle.cfdg
# experiment00a.cfdg		 tangle_v2.cfdg
# experiment.cfdg			 tests
# expression.cfdg			 thingy.cfdg
# firtree.cfdg			 thorns.cfdg
# from flight.cfdg		 Tileworks 19 - Gallery.cfdg
# Frost Corner.cfdg		 Torus.cfdg
# funky_flower.cfdg		 tree_number_5.cfdg
# funky_flower_v2.cfdg		 trestough3.cfdg
# furball.cfdg			 triples.cfdg
# galaxy.cfdg			 triples_v2.cfdg
# geometri3.cfdg			 underground.cfdg
# grain.cfdg			 underground_v2.cfdg
# greensquares.cfdg		 unity.cfdg
# hidden.cfdg			 weighting_demo.cfdg
# Hyperbolic_Heat.cfdg		 weighting_demo_v2.cfdg
# i_curves.cfdg			 welcome.cfdg
# i_curves_v2.cfdg		 welcome_v2.cfdg
# insectivore.cfdg		 Whorld.cfdg
# Inside My Heart Is Burning.cfdg  wire.cfdg
# i_pix.cfdg			 wooooooo.cfdg
# i_pix_v2.cfdg			 xmas.cfdg
# i_polygons.cfdg			 xxx.cfdg
# i_polygons_v2.cfdg		 yinyangthing.cfdg
# kiss.cfdg			 ziggy.cfdg
# Kochlea2.cfdg			 ziggy_v2.cfdg
# lesson2.cfdg

# %%
background { b -.1 sat 0.45 hue 44 }
background { b -.8 sat 1  h -10} 

background { b 36 sat 0.4 hue 24 }

# %%
# !./context-free/cfdg -s 640 context-free/input/experiment000a.cfdg context-free/output/experiment000a.png
from PIL import Image
view = Image.open("context-free/output/experiment000a.png")
view
# Out:
# Reading rules file context-free/input/experiment000a.cfdg
# 10 rules loaded
# Generating 8bit color PNG image, variation HTRIDD...
# 640w x 640h pixel image.82 expansions to doK
# Generating...
#
# Sorting shapes...
#
# Rendering...
# [******************************....................]
# Writing 640w x 640h pixel image...
#     529,931 shapes
# DONE!
# The output file name is context-free/output/experiment000a.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x7F2198DEAB90>

# %%
# %%writefile context-free/input/thorns.cfdg
# startshape HORN
# background { b -0.1; h 220; sat 0.7 }
#
# rule THORN {
# 	CIRCLE {}
# 	THORN {h -20  s 0.95 y 0.3 }
# }
#
# rule THORNS {
# 	THORN {}
# 	THORNS {h 2.49 sat 0.5116 s 25 r -85 y 6.2 }
# 	THORNS {h 2.49 sat 0.5116 s 25 r 85 y 6.2 }
# 	THORNS {h 2.49 sat 0.5116 s 25 y 6.2 }
# }
#
# rule HORN {
# 	THORNS {r 25}
# 	THORNS {r 35}
# 	THORNS {r 25}
# 	THORNS {r 15}
# }
# Out:
# Overwriting context-free/input/thorns.cfdg

# %%
# !./context-free/cfdg -s 640 context-free/input/thorns.cfdg context-free/output/thorns.png
from PIL import Image
view = Image.open("context-free/output/thorns.png")
view
# Out:
# Reading rules file context-free/input/thorns.cfdg
# Error in thorns.cfdg at line 2:19-2:20 - syntax error
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x7F2198DEA2D0>

# %%
# %load context-free/input/PIUMA.cfdg
startshape PIUMA
background { b -.8 sat 1  h -10} 
rule PIUMA {
200 * {y .1 s .9975 r -.1}  ELE {s .04}
100 * {y -.1 s .993 r .2}  ELE {s .04}
}
rule ELE {
EL {x 1.6  r 90 }
EL {x  -1.6  r 90 flip 180 }
}
rule EL{
PEN{}
EL{s .999 r -.103 x .2}
}
rule EL 0.000251 {
EL{flip 180}
}
rule EL 0.002 {
EL2{s .8}
//EL2{flip 0 s .8}
}
rule EL2{
PEN{}
EL2{s .9996 r -.08381 x .2}
}
rule EL2 0.000251 {
EL2{flip 180}
}
rule PEN 3 {
PENNA {b 1}
}
rule PEN{
//PENNA {b -1 z -10}
}
rule PENNA{
CIRCLE{a -.99 s 35 b -1 z -2}
//CIRCLE{a -.998 s 10  z -1}
CIRCLE{a -.7}
}

# %%
# !./context-free/cfdg -s 640 context-free/input/PIUMA.cfdg context-free/output/PIUMA-2.png
from PIL import Image
view = Image.open("context-free/output/PIUMA-2.png")
view
# Out:
# Reading rules file context-free/input/PIUMA.cfdg
# 10 rules loaded
# Generating 8bit color PNG image, variation UPGPGG...
# 640w x 640h pixel image. expansions to do
# Generating...
#
# Sorting shapes...
#
# Rendering...
# [**************************************............]
# Writing 640w x 640h pixel image...
#     1,014,934 shapes
# DONE!
# The output file name is context-free/output/PIUMA-2.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x7F03AE0CDFD0>

# %%
# !ls context-free/input
# Out:
# 1128211071.cfdg		      Moire Swirls 2.cfdg
# 1128941024.cfdg		      mtree.cfdg
# 1130225163.cfdg		      mtree-j.cfdg
# 1145254241.cfdg		      mtree_v2.cfdg
# Agglomeration_3200_2400.cfdg  multiverse.cfdg
# aliastest.cfdg		      Nebula.cfdg
# alphabet.cfdg		      octopi.cfdg
# anchient-map.cfdg	      octopi_v2.cfdg
# ANCIENTMAP2.cfdg	      PIUMA.cfdg
# ancient-scripts.cfdg	      Plagium.cfdg
# bleak.cfdg		      point.cfdg
# Bubbles.cfdg		      quadcity.cfdg
# chanukah.cfdg		      quadcity_v2.cfdg
# cilia.cfdg		      rendering-tests.cfdg
# ciliasun.cfdg		      rose.cfdg
# ciliasun_v2.cfdg	      rose_v2.cfdg
# clouds.cfdg		      seasons.cfdg
# confined.cfdg		      sierpinski.cfdg
# conspiracy1.cfdg	      sierpinski_v2.cfdg
# crystals.cfdg		      snowflake.cfdg
# cubefield.cfdg		      snowflake_v2.cfdg
# demo1.cfdg		      softcore2.cfdg
# demo1_v2.cfdg		      softercore.cfdg
# demo2.cfdg		      stairway_II.cfdg
# demo2_v2.cfdg		      string-theory.cfdg
# Document11.cfdg		      tangle.cfdg
# expression.cfdg		      tangle_v2.cfdg
# from flight.cfdg	      tests
# funky_flower.cfdg	      thingy.cfdg
# funky_flower_v2.cfdg	      thorns.cfdg
# galaxy.cfdg		      Tileworks 19 - Gallery.cfdg
# geometri3.cfdg		      Torus.cfdg
# grain.cfdg		      tree_number_5.cfdg
# hidden.cfdg		      trestough3.cfdg
# i_curves.cfdg		      triples.cfdg
# i_curves_v2.cfdg	      triples_v2.cfdg
# insectivore.cfdg	      underground.cfdg
# i_pix.cfdg		      underground_v2.cfdg
# i_pix_v2.cfdg		      unity.cfdg
# i_polygons.cfdg		      weighting_demo.cfdg
# i_polygons_v2.cfdg	      weighting_demo_v2.cfdg
# kiss.cfdg		      welcome.cfdg
# Kochlea2.cfdg		      welcome_v2.cfdg
# lesson2.cfdg		      Whorld.cfdg
# lesson2_v2.cfdg		      wire.cfdg
# lesson.cfdg		      wooooooo.cfdg
# lesson_v2.cfdg		      xmas.cfdg
# line_ending_test_cr.cfdg      yinyangthing.cfdg
# line_ending_test_crlf.cfdg    ziggy.cfdg
# line_ending_test_lf.cfdg      ziggy_v2.cfdg
# line_ending_test_multi.cfdg

# %%
# %%writefile context-free/input/ANCIENTMAP2.cfdg
# startshape ANCIENTMAP2
#
# background { b -.1 sat 0.45 hue 44 }
#
# rule ANCIENTMAP2 {
# 	WALL1 {b 0.1 hue 34}
# 	WALL1 {b 0.1 r 180 hue 34}
# }
#
# rule WALL1 {
# 	WALL1{y 0.95 r 1 s 0.975}
# }
#
# rule WALL1 {
# 	SQUARE {}
# 	WALL1{y 0.95 r -1 s 0.975 sat 0.1 b .01 hue .1}
# }
#
# rule WALL1 0.09 {
# 	SQUARE {}
# 	WALL1{y 0.95 r 45 s 0.975}
# 	WALL1{y 0.95 r -45 s 0.975}
# }
#
# rule WALL1 0.005 {
# 	WALL1{y 0.97 r 45 s 1.5}
# 	WALL1{y 0.97 r -45 s 1.5}
# }
# Out:
# Overwriting context-free/input/ANCIENTMAP2.cfdg

# %%
http://www.decontextualize.com/teaching/a2z/context-free-as-in-speech/

# %%
# %%writefile context-free/example/ContextFree.java
# ContextFree cf = new ContextFree();
# cf.addRule("S", "NP VP");
# cf.addRule("NP", "the N");
# cf.addRule("N", "cat");
# cf.addRule("N", "dog");
# cf.addRule("N", "weinermobile");
# cf.addRule("N", "duchess");
# cf.addRule("VP", "V the N");
# cf.addRule("V", "sees");
# cf.addRule("V", "chases");
# cf.addRule("V", "lusts after");
# cf.addRule("V", "blames");
# cf.expand("S");
# System.out.println();
# Out:
# Writing context-free/example/ContextFree.java

# %%
# %%writefile context-free/example/ContextRule.java
# import java.util.ArrayList;
# public class ContextRule {
#   private ArrayList<String> expansions;
#   private String rule;
#   public ContextRule(String rule_) {
#     expansions = new ArrayList<String>();
#     rule = rule_;
#   }
#   public void addExpansion(String expansion) {
#     expansions.add(expansion);
#   }
#   public String getRandomExpansion() {
#     int randomIndex = (int)(Math.random() * expansions.size());
#     return expansions.get(randomIndex);
#   }
#   public void dump() {
#     System.out.print(rule + " -> ");
#     System.out.println(expansions);
#   }
# }
# Out:
# Writing context-free/example/ContextRule.java

# %%
# %%writefile context-free/example/HashMap.java
# private HashMap<String, ContextRule> rules;
# public void addRule(String rule, String expansion) {
#   if (rules.containsKey(rule)) {
#     ContextRule cr = rules.get(rule);
#     cr.addExpansion(expansion);
#   }
#   else {
#     ContextRule cr = new ContextRule(rule);
#     cr.addExpansion(expansion);
#     rules.put(rule, cr);
#   }
# }
# Out:
# Writing context-free/example/HashMap.java

# %% [markdown]
# ###  GOOD ---  GOOD ---  GOOD ---  GOOD ---  GOOD ---

# %% [markdown]
# # THE NEXT LINE ---- RUNS THE JAVA ----

# %% [raw]
# ----------------  Run from the terminal  ---------------------
# java ContextFilter <test.grammar

# %% [markdown]
# # - - - - - THE ABOVE LINE RUNS THE JAVA- - - - - - - - - - - -

# %%
# !java context-free/example/ContextFilter <context-free/example/test.grammar
# Out:
# Error: Could not find or load main class context-free.example.ContextFilter

# %% [markdown]
# ## This is the test.grammar to edit

# %%
# %%writefile context-free/example/test.grammar
# # clauses
# S -> NP VP
# S -> Interj NP VP
# NP -> Det N
# NP -> Det N that VP
# NP -> Det Adj N
# VP -> Vtrans NP   # transitive verbs have direct objects
# VP -> Vintr       # intransitive verbs have no direct object
#
# # terminals
# Interj -> oh, | my, | wow, | damn, | jeez | man | MMM
# Det -> this | that | the | a
# N -> amoeba | dichotomy | seagull | trombone | corsage | restaurant | suburb
# Adj -> bald | smug | important | tame | overstaffed | luxurious | blue | mean | worried
# Vtrans -> computes | examines | foregrounds | prefers | interprets | spins | ignores | pokes
# Vintr -> coughs | daydreams | whines | slobbers | vocalizes | sneezes | points | mummers
# Out:
# Overwriting context-free/example/test.grammar

# %%
S -> NP VP
NP -> the N
VP -> V
VP -> V NP
N -> amoeba
N -> dichotomy
N -> seagull
V -> shook
V -> escaped
V -> changed

# %% [markdown]
# # These files below were required to compile ContextFilter.java

# %% [markdown]
# #  GOOD ---  GOOD ---  GOOD ---  GOOD ---  GOOD ---

# %%
# %%writefile context-free/example/ContextFilter.java
# import java.util.regex.*;
# import com.decontextualize.a2z.TextFilter;
#
# public class ContextFilter extends TextFilter {
#
#   public static void main(String[] args) {
#     new ContextFilter().run();
#   }
#
#   private ContextFree cfg;
#
#   public void begin() {
#     cfg = new ContextFree();
#   }
#
#   public void eachLine(String line) {
#
#     // remove comments
#     line = line.replaceAll("#.*$", "");
#
#     // get production rules, store in given ContextFree object
#     Pattern rulePattern = Pattern.compile("(\\w+) *-> *(.*)");
#     Matcher m = rulePattern.matcher(line);
#     if (m.find()) {
#       String rule = m.group(1);
#       String expansion = m.group(2);
#       String[] expansions = expansion.split("\\s*\\|\\s*");
#       for (String s: expansions) {
#         cfg.addRule(rule, s);
#       }
#     }
#
#   }
#
#   public void end() {
# //    cfg.dump();
#     cfg.expand("S");
#     println();
#   }
#
# }
# Out:
# Overwriting context-free/example/ContextFilter.java

# %%
# %%writefile context-free/example/eachLine.java
# public void eachLine(String line) {
#   line = line.replaceAll("#.*$", ""); // remove comments
#   Pattern rulePattern = Pattern.compile("(\\w+) *-> *(.*)"); // Sym -> Expansion
#   Matcher m = rulePattern.matcher(line);
#   if (m.find()) {
#     String rule = m.group(1);
#     String expansion = m.group(2);
#     String[] expansions = expansion.split("\\s*\\|\\s*");
#     for (String s: expansions) {
#       cfg.addRule(rule, s);
#     }
#   }
# }
# Out:
# Writing context-free/example/eachLine.java

# %%
# %%writefile context-free/example/expand.java
# public void expand(String current) {
#   if (!rules.containsKey(current)) {
#     renderExpansion(current);
#   }
#   else {
#     ContextRule cr = rules.get(current);
#     String[] toExpand = cr.getRandomExpansion().split(" ");
#     for (String s: toExpand) {
#       expand(s);
#     }
#   }
# }
# Out:
# Writing context-free/example/expand.java

# %%
# !rm context-free/input/xxx.cfdg
# Out:
# rm: cannot remove 'context-free/input/xxx.cfdg': No such file or directory

# %%
var grammar = new RiGrammar();
grammar.addRule('<start>', 'Once upon a time, there was a <adj> <hero>.');
grammar.addRule('<hero>', 'fairy | unicorn | dragon | bear');
grammar.addRule('<adj>', 'smart | pretty | smelly | funny | angry');
# Out:
# Writing context-free/input/xxx.cfdg

# %%
# !context-free/cfdg /context-free/input/xxx.cfdg
# Out:
# Couldn't open rules file /context-free/input/xxx.cfdg

# %%
from nltk.parse.generate import generate
help(generate)
# Out:
# Help on function generate in module nltk.parse.generate:
#
# generate(grammar, start=None, depth=None, n=None)
#     Generates an iterator of all sentences from a CFG.
#
#     :param grammar: The Grammar used to generate sentences.
#     :param start: The Nonterminal from which to start generate sentences.
#     :param depth: The maximal depth of the generated tree.
#     :param n: The maximum number of sentences to return.
#     :return: An iterator of lists of terminal tokens.

# %%
from nltk.parse.generate import generate
help(demo_grammar)
# Out:
# no Python documentation found for "S -> NP VP\n  NP -> Det N\n  PP -> P NP\n  VP -> 'slept' | 'saw' NP | 'walked' PP\n  Det -> 'the' | 'a'\n  N -> 'man' | 'park' | 'dog'\n  P -> 'in' | 'with'"

# %%
# %%writefile My_Nltk
#     S -> E NP VP
#     E -> 'Guess What ?' | 'Did you know?' | 'I saw' | 'Did you see?' | 'Yesterday'
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept' | 'observed' NP | 'walked' | 'ran' | 'jumped' | 'spoke with' PP
#     Det -> 'the' | 'a'
#     N -> 'man' | 'woman' | 'dog' |'bird' | 'cat' | 'girl' | 'boy'
#     P -> 'over' | 'with' | 'around' | 'next to' | 'behind' | 'in front of'
# Out:
# Overwriting My_Nltk

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG
F = open('My_Nltk','r') 
grammar = CFG.fromstring(F)
print(grammar)
# Out:
# Grammar with 29 productions (start state = S)
#     S -> E NP VP
#     E -> 'Guess What ?'
#     E -> 'Did you know?'
#     E -> 'I saw'
#     E -> 'Did you see?'
#     E -> 'Yesterday'
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept'
#     VP -> 'observed' NP
#     VP -> 'walked'
#     VP -> 'ran'
#     VP -> 'jumped'
#     VP -> 'spoke with' PP
#     Det -> 'the'
#     Det -> 'a'
#     N -> 'man'
#     N -> 'woman'
#     N -> 'dog'
#     N -> 'bird'
#     N -> 'cat'
#     N -> 'girl'
#     N -> 'boy'
#     P -> 'over'
#     P -> 'with'
#     P -> 'around'
#     P -> 'next to'
#     P -> 'behind'
#     P -> 'in front of'

# %%
for sentence in generate(grammar, depth=6):
    print(' '.join(sentence))
# Out:
# Guess What ? the man slept
# Guess What ? the man observed the man
# Guess What ? the man observed the woman
# Guess What ? the man observed the dog
# Guess What ? the man observed the bird
# Guess What ? the man observed the cat
# Guess What ? the man observed the girl
# Guess What ? the man observed the boy
# Guess What ? the man observed a man
# Guess What ? the man observed a woman
# Guess What ? the man observed a dog
# Guess What ? the man observed a bird
# Guess What ? the man observed a cat
# Guess What ? the man observed a girl
# Guess What ? the man observed a boy
# Guess What ? the man walked
# Guess What ? the man ran
# Guess What ? the man jumped
# Guess What ? the man spoke with over the man
# Guess What ? the man spoke with over the woman
# Guess What ? the man spoke with over the dog
# Guess What ? the man spoke with over the bird
# Guess What ? the man spoke with over the cat
# Guess What ? the man spoke with over the girl
# Guess What ? the man spoke with over the boy
# Guess What ? the man spoke with over a man
# Guess What ? the man spoke with over a woman
# Guess What ? the man spoke with over a dog
# Guess What ? the man spoke with over a bird
# Guess What ? the man spoke with over a cat
# Guess What ? the man spoke with over a girl
# Guess What ? the man spoke with over a boy
# Guess What ? the man spoke with with the man
# Guess What ? the man spoke with with the woman
# Guess What ? the man spoke with with the dog
# Guess What ? the man spoke with with the bird
# Guess What ? the man spoke with with the cat
# Guess What ? the man spoke with with the girl
# Guess What ? the man spoke with with the boy
# Guess What ? the man spoke with with a man
# Guess What ? the man spoke with with a woman
# Guess What ? the man spoke with with a dog
# Guess What ? the man spoke with with a bird
# Guess What ? the man spoke with with a cat
# Guess What ? the man spoke with with a girl
# Guess What ? the man spoke with with a boy
# Guess What ? the man spoke with around the man
# Guess What ? the man spoke with around the woman
# Guess What ? the man spoke with around the dog
# Guess What ? the man spoke with around the bird
# Guess What ? the man spoke with around the cat
# Guess What ? the man spoke with around the girl
# Guess What ? the man spoke with around the boy
# Guess What ? the man spoke with around a man
# Guess What ? the man spoke with around a woman
# Guess What ? the man spoke with around a dog
# Guess What ? the man spoke with around a bird
# Guess What ? the man spoke with around a cat
# Guess What ? the man spoke with around a girl
# Guess What ? the man spoke with around a boy
# Guess What ? the man spoke with next to the man
# Guess What ? the man spoke with next to the woman
# Guess What ? the man spoke with next to the dog
# Guess What ? the man spoke with next to the bird
# Guess What ? the man spoke with next to the cat
# Guess What ? the man spoke with next to the girl
# Guess What ? the man spoke with next to the boy
# Guess What ? the man spoke with next to a man
# Guess What ? the man spoke with next to a woman
# Guess What ? the man spoke with next to a dog
# Guess What ? the man spoke with next to a bird
# Guess What ? the man spoke with next to a cat
# Guess What ? the man spoke with next to a girl
# Guess What ? the man spoke with next to a boy
# Guess What ? the man spoke with behind the man
# Guess What ? the man spoke with behind the woman
# Guess What ? the man spoke with behind the dog
# Guess What ? the man spoke with behind the bird
# Guess What ? the man spoke with behind the cat
# Guess What ? the man spoke with behind the girl
# Guess What ? the man spoke with behind the boy
# Guess What ? the man spoke with behind a man
# Guess What ? the man spoke with behind a woman
# Guess What ? the man spoke with behind a dog
# Guess What ? the man spoke with behind a bird
# Guess What ? the man spoke with behind a cat
# Guess What ? the man spoke with behind a girl
# Guess What ? the man spoke with behind a boy
# Guess What ? the man spoke with in front of the man
# Guess What ? the man spoke with in front of the woman
# Guess What ? the man spoke with in front of the dog
# Guess What ? the man spoke with in front of the bird
# Guess What ? the man spoke with in front of the cat
# Guess What ? the man spoke with in front of the girl
# Guess What ? the man spoke with in front of the boy
# Guess What ? the man spoke with in front of a man
# Guess What ? the man spoke with in front of a woman
# Guess What ? the man spoke with in front of a dog
# Guess What ? the man spoke with in front of a bird
# Guess What ? the man spoke with in front of a cat
# Guess What ? the man spoke with in front of a girl
# Guess What ? the man spoke with in front of a boy
# Guess What ? the woman slept
# Guess What ? the woman observed the man
# Guess What ? the woman observed the woman
# Guess What ? the woman observed the dog
# Guess What ? the woman observed the bird
# Guess What ? the woman observed the cat
# Guess What ? the woman observed the girl
# Guess What ? the woman observed the boy
# Guess What ? the woman observed a man
# Guess What ? the woman observed a woman
# Guess What ? the woman observed a dog
# Guess What ? the woman observed a bird
# Guess What ? the woman observed a cat
# Guess What ? the woman observed a girl
# Guess What ? the woman observed a boy
# Guess What ? the woman walked
# Guess What ? the woman ran
# Guess What ? the woman jumped
# Guess What ? the woman spoke with over the man
# Guess What ? the woman spoke with over the woman
# Guess What ? the woman spoke with over the dog
# Guess What ? the woman spoke with over the bird
# Guess What ? the woman spoke with over the cat
# Guess What ? the woman spoke with over the girl
# Guess What ? the woman spoke with over the boy
# Guess What ? the woman spoke with over a man
# Guess What ? the woman spoke with over a woman
# Guess What ? the woman spoke with over a dog
# Guess What ? the woman spoke with over a bird
# Guess What ? the woman spoke with over a cat
# Guess What ? the woman spoke with over a girl
# Guess What ? the woman spoke with over a boy
# Guess What ? the woman spoke with with the man
# Guess What ? the woman spoke with with the woman
# Guess What ? the woman spoke with with the dog
# Guess What ? the woman spoke with with the bird
# Guess What ? the woman spoke with with the cat
# Guess What ? the woman spoke with with the girl
# Guess What ? the woman spoke with with the boy
# Guess What ? the woman spoke with with a man
# Guess What ? the woman spoke with with a woman
# Guess What ? the woman spoke with with a dog
# Guess What ? the woman spoke with with a bird
# Guess What ? the woman spoke with with a cat
# Guess What ? the woman spoke with with a girl
# Guess What ? the woman spoke with with a boy
# Guess What ? the woman spoke with around the man
# Guess What ? the woman spoke with around the woman
# Guess What ? the woman spoke with around the dog
# Guess What ? the woman spoke with around the bird
# Guess What ? the woman spoke with around the cat
# Guess What ? the woman spoke with around the girl
# Guess What ? the woman spoke with around the boy
# Guess What ? the woman spoke with around a man
# Guess What ? the woman spoke with around a woman
# Guess What ? the woman spoke with around a dog
# Guess What ? the woman spoke with around a bird
# Guess What ? the woman spoke with around a cat
# Guess What ? the woman spoke with around a girl
# Guess What ? the woman spoke with around a boy
# Guess What ? the woman spoke with next to the man
# Guess What ? the woman spoke with next to the woman
# Guess What ? the woman spoke with next to the dog
# Guess What ? the woman spoke with next to the bird
# Guess What ? the woman spoke with next to the cat
# Guess What ? the woman spoke with next to the girl
# Guess What ? the woman spoke with next to the boy
# Guess What ? the woman spoke with next to a man
# Guess What ? the woman spoke with next to a woman
# Guess What ? the woman spoke with next to a dog
# Guess What ? the woman spoke with next to a bird
# Guess What ? the woman spoke with next to a cat
# Guess What ? the woman spoke with next to a girl
# Guess What ? the woman spoke with next to a boy
# Guess What ? the woman spoke with behind the man
# Guess What ? the woman spoke with behind the woman
# Guess What ? the woman spoke with behind the dog
# Guess What ? the woman spoke with behind the bird
# Guess What ? the woman spoke with behind the cat
# Guess What ? the woman spoke with behind the girl
# Guess What ? the woman spoke with behind the boy
# Guess What ? the woman spoke with behind a man
# Guess What ? the woman spoke with behind a woman
# Guess What ? the woman spoke with behind a dog
# Guess What ? the woman spoke with behind a bird
# Guess What ? the woman spoke with behind a cat
# Guess What ? the woman spoke with behind a girl
# Guess What ? the woman spoke with behind a boy
# Guess What ? the woman spoke with in front of the man
# Guess What ? the woman spoke with in front of the woman
# Guess What ? the woman spoke with in front of the dog
# Guess What ? the woman spoke with in front of the bird
# Guess What ? the woman spoke with in front of the cat
# Guess What ? the woman spoke with in front of the girl
# Guess What ? the woman spoke with in front of the boy
# Guess What ? the woman spoke with in front of a man
# Guess What ? the woman spoke with in front of a woman
# Guess What ? the woman spoke with in front of a dog
# Guess What ? the woman spoke with in front of a bird
# Guess What ? the woman spoke with in front of a cat
# Guess What ? the woman spoke with in front of a girl
# Guess What ? the woman spoke with in front of a boy
# Guess What ? the dog slept
# Guess What ? the dog observed the man
# Guess What ? the dog observed the woman
# Guess What ? the dog observed the dog
# Guess What ? the dog observed the bird
# Guess What ? the dog observed the cat
# Guess What ? the dog observed the girl
# Guess What ? the dog observed the boy
# Guess What ? the dog observed a man
# Guess What ? the dog observed a woman
# Guess What ? the dog observed a dog
# Guess What ? the dog observed a bird
# Guess What ? the dog observed a cat
# Guess What ? the dog observed a girl
# Guess What ? the dog observed a boy
# Guess What ? the dog walked
# Guess What ? the dog ran
# Guess What ? the dog jumped
# Guess What ? the dog spoke with over the man
# Guess What ? the dog spoke with over the woman
# Guess What ? the dog spoke with over the dog
# Guess What ? the dog spoke with over the bird
# Guess What ? the dog spoke with over the cat
# Guess What ? the dog spoke with over the girl
# Guess What ? the dog spoke with over the boy
# Guess What ? the dog spoke with over a man
# Guess What ? the dog spoke with over a woman
# Guess What ? the dog spoke with over a dog
# Guess What ? the dog spoke with over a bird
# Guess What ? the dog spoke with over a cat
# Guess What ? the dog spoke with over a girl
# Guess What ? the dog spoke with over a boy
# Guess What ? the dog spoke with with the man
# Guess What ? the dog spoke with with the woman
# Guess What ? the dog spoke with with the dog
# Guess What ? the dog spoke with with the bird
# Guess What ? the dog spoke with with the cat
# Guess What ? the dog spoke with with the girl
# Guess What ? the dog spoke with with the boy
# Guess What ? the dog spoke with with a man
# Guess What ? the dog spoke with with a woman
# Guess What ? the dog spoke with with a dog
# Guess What ? the dog spoke with with a bird
# Guess What ? the dog spoke with with a cat
# Guess What ? the dog spoke with with a girl
# Guess What ? the dog spoke with with a boy
# Guess What ? the dog spoke with around the man
# Guess What ? the dog spoke with around the woman
# Guess What ? the dog spoke with around the dog
# Guess What ? the dog spoke with around the bird
# Guess What ? the dog spoke with around the cat
# Guess What ? the dog spoke with around the girl
# Guess What ? the dog spoke with around the boy
# Guess What ? the dog spoke with around a man
# Guess What ? the dog spoke with around a woman
# Guess What ? the dog spoke with around a dog
# Guess What ? the dog spoke with around a bird
# Guess What ? the dog spoke with around a cat
# Guess What ? the dog spoke with around a girl
# Guess What ? the dog spoke with around a boy
# Guess What ? the dog spoke with next to the man
# Guess What ? the dog spoke with next to the woman
# Guess What ? the dog spoke with next to the dog
# Guess What ? the dog spoke with next to the bird
# Guess What ? the dog spoke with next to the cat
# Guess What ? the dog spoke with next to the girl
# Guess What ? the dog spoke with next to the boy
# Guess What ? the dog spoke with next to a man
# Guess What ? the dog spoke with next to a woman
# Guess What ? the dog spoke with next to a dog
# Guess What ? the dog spoke with next to a bird
# Guess What ? the dog spoke with next to a cat
# Guess What ? the dog spoke with next to a girl
# Guess What ? the dog spoke with next to a boy
# Guess What ? the dog spoke with behind the man
# Guess What ? the dog spoke with behind the woman
# Guess What ? the dog spoke with behind the dog
# Guess What ? the dog spoke with behind the bird
# Guess What ? the dog spoke with behind the cat
# Guess What ? the dog spoke with behind the girl
# Guess What ? the dog spoke with behind the boy
# Guess What ? the dog spoke with behind a man
# Guess What ? the dog spoke with behind a woman
# Guess What ? the dog spoke with behind a dog
# Guess What ? the dog spoke with behind a bird
# Guess What ? the dog spoke with behind a cat
# Guess What ? the dog spoke with behind a girl
# Guess What ? the dog spoke with behind a boy
# Guess What ? the dog spoke with in front of the man
# Guess What ? the dog spoke with in front of the woman
# Guess What ? the dog spoke with in front of the dog
# Guess What ? the dog spoke with in front of the bird
# Guess What ? the dog spoke with in front of the cat
# Guess What ? the dog spoke with in front of the girl
# Guess What ? the dog spoke with in front of the boy
# Guess What ? the dog spoke with in front of a man
# Guess What ? the dog spoke with in front of a woman
# Guess What ? the dog spoke with in front of a dog
# Guess What ? the dog spoke with in front of a bird
# Guess What ? the dog spoke with in front of a cat
# Guess What ? the dog spoke with in front of a girl
# Guess What ? the dog spoke with in front of a boy
# Guess What ? the bird slept
# Guess What ? the bird observed the man
# Guess What ? the bird observed the woman
# Guess What ? the bird observed the dog
# Guess What ? the bird observed the bird
# Guess What ? the bird observed the cat
# Guess What ? the bird observed the girl
# Guess What ? the bird observed the boy
# Guess What ? the bird observed a man
# Guess What ? the bird observed a woman
# Guess What ? the bird observed a dog
# Guess What ? the bird observed a bird
# Guess What ? the bird observed a cat
# Guess What ? the bird observed a girl
# Guess What ? the bird observed a boy
# Guess What ? the bird walked
# Guess What ? the bird ran
# Guess What ? the bird jumped
# Guess What ? the bird spoke with over the man
# Guess What ? the bird spoke with over the woman
# Guess What ? the bird spoke with over the dog
# Guess What ? the bird spoke with over the bird
# Guess What ? the bird spoke with over the cat
# Guess What ? the bird spoke with over the girl
# Guess What ? the bird spoke with over the boy
# Guess What ? the bird spoke with over a man
# Guess What ? the bird spoke with over a woman
# Guess What ? the bird spoke with over a dog
# Guess What ? the bird spoke with over a bird
# Guess What ? the bird spoke with over a cat
# Guess What ? the bird spoke with over a girl
# Guess What ? the bird spoke with over a boy
# Guess What ? the bird spoke with with the man
# Guess What ? the bird spoke with with the woman
# Guess What ? the bird spoke with with the dog
# Guess What ? the bird spoke with with the bird
# Guess What ? the bird spoke with with the cat
# Guess What ? the bird spoke with with the girl
# Guess What ? the bird spoke with with the boy
# Guess What ? the bird spoke with with a man
# Guess What ? the bird spoke with with a woman
# Guess What ? the bird spoke with with a dog
# Guess What ? the bird spoke with with a bird
# Guess What ? the bird spoke with with a cat
# Guess What ? the bird spoke with with a girl
# Guess What ? the bird spoke with with a boy
# Guess What ? the bird spoke with around the man
# Guess What ? the bird spoke with around the woman
# Guess What ? the bird spoke with around the dog
# Guess What ? the bird spoke with around the bird
# Guess What ? the bird spoke with around the cat
# Guess What ? the bird spoke with around the girl
# Guess What ? the bird spoke with around the boy
# Guess What ? the bird spoke with around a man
# Guess What ? the bird spoke with around a woman
# Guess What ? the bird spoke with around a dog
# Guess What ? the bird spoke with around a bird
# Guess What ? the bird spoke with around a cat
# Guess What ? the bird spoke with around a girl
# Guess What ? the bird spoke with around a boy
# Guess What ? the bird spoke with next to the man
# Guess What ? the bird spoke with next to the woman
# Guess What ? the bird spoke with next to the dog
# Guess What ? the bird spoke with next to the bird
# Guess What ? the bird spoke with next to the cat
# Guess What ? the bird spoke with next to the girl
# Guess What ? the bird spoke with next to the boy
# Guess What ? the bird spoke with next to a man
# Guess What ? the bird spoke with next to a woman
# Guess What ? the bird spoke with next to a dog
# Guess What ? the bird spoke with next to a bird
# Guess What ? the bird spoke with next to a cat
# Guess What ? the bird spoke with next to a girl
# Guess What ? the bird spoke with next to a boy
# Guess What ? the bird spoke with behind the man
# Guess What ? the bird spoke with behind the woman
# Guess What ? the bird spoke with behind the dog
# Guess What ? the bird spoke with behind the bird
# Guess What ? the bird spoke with behind the cat
# Guess What ? the bird spoke with behind the girl
# Guess What ? the bird spoke with behind the boy
# Guess What ? the bird spoke with behind a man
# Guess What ? the bird spoke with behind a woman
# Guess What ? the bird spoke with behind a dog
# Guess What ? the bird spoke with behind a bird
# Guess What ? the bird spoke with behind a cat
# Guess What ? the bird spoke with behind a girl
# Guess What ? the bird spoke with behind a boy
# Guess What ? the bird spoke with in front of the man
# Guess What ? the bird spoke with in front of the woman
# Guess What ? the bird spoke with in front of the dog
# Guess What ? the bird spoke with in front of the bird
# Guess What ? the bird spoke with in front of the cat
# Guess What ? the bird spoke with in front of the girl
# Guess What ? the bird spoke with in front of the boy
# Guess What ? the bird spoke with in front of a man
# Guess What ? the bird spoke with in front of a woman
# Guess What ? the bird spoke with in front of a dog
# Guess What ? the bird spoke with in front of a bird
# Guess What ? the bird spoke with in front of a cat
# Guess What ? the bird spoke with in front of a girl
# Guess What ? the bird spoke with in front of a boy
# Guess What ? the cat slept
# Guess What ? the cat observed the man
# Guess What ? the cat observed the woman
# Guess What ? the cat observed the dog
# Guess What ? the cat observed the bird
# Guess What ? the cat observed the cat
# Guess What ? the cat observed the girl
# Guess What ? the cat observed the boy
# Guess What ? the cat observed a man
# Guess What ? the cat observed a woman
# Guess What ? the cat observed a dog
# Guess What ? the cat observed a bird
# Guess What ? the cat observed a cat
# Guess What ? the cat observed a girl
# Guess What ? the cat observed a boy
# Guess What ? the cat walked
# Guess What ? the cat ran
# Guess What ? the cat jumped
# Guess What ? the cat spoke with over the man
# Guess What ? the cat spoke with over the woman
# Guess What ? the cat spoke with over the dog
# Guess What ? the cat spoke with over the bird
# Guess What ? the cat spoke with over the cat
# Guess What ? the cat spoke with over the girl
# Guess What ? the cat spoke with over the boy
# Guess What ? the cat spoke with over a man
# Guess What ? the cat spoke with over a woman
# Guess What ? the cat spoke with over a dog
# Guess What ? the cat spoke with over a bird
# Guess What ? the cat spoke with over a cat
# Guess What ? the cat spoke with over a girl
# Guess What ? the cat spoke with over a boy
# Guess What ? the cat spoke with with the man
# Guess What ? the cat spoke with with the woman
# Guess What ? the cat spoke with with the dog
# Guess What ? the cat spoke with with the bird
# Guess What ? the cat spoke with with the cat
# Guess What ? the cat spoke with with the girl
# Guess What ? the cat spoke with with the boy
# Guess What ? the cat spoke with with a man
# Guess What ? the cat spoke with with a woman
# Guess What ? the cat spoke with with a dog
# Guess What ? the cat spoke with with a bird
# Guess What ? the cat spoke with with a cat
# Guess What ? the cat spoke with with a girl
# Guess What ? the cat spoke with with a boy
# Guess What ? the cat spoke with around the man
# Guess What ? the cat spoke with around the woman
# Guess What ? the cat spoke with around the dog
# Guess What ? the cat spoke with around the bird
# Guess What ? the cat spoke with around the cat
# Guess What ? the cat spoke with around the girl
# Guess What ? the cat spoke with around the boy
# Guess What ? the cat spoke with around a man
# Guess What ? the cat spoke with around a woman
# Guess What ? the cat spoke with around a dog
# Guess What ? the cat spoke with around a bird
# Guess What ? the cat spoke with around a cat
# Guess What ? the cat spoke with around a girl
# Guess What ? the cat spoke with around a boy
# Guess What ? the cat spoke with next to the man
# Guess What ? the cat spoke with next to the woman
# Guess What ? the cat spoke with next to the dog
# Guess What ? the cat spoke with next to the bird
# Guess What ? the cat spoke with next to the cat
# Guess What ? the cat spoke with next to the girl
# Guess What ? the cat spoke with next to the boy
# Guess What ? the cat spoke with next to a man
# Guess What ? the cat spoke with next to a woman
# Guess What ? the cat spoke with next to a dog
# Guess What ? the cat spoke with next to a bird
# Guess What ? the cat spoke with next to a cat
# Guess What ? the cat spoke with next to a girl
# Guess What ? the cat spoke with next to a boy
# Guess What ? the cat spoke with behind the man
# Guess What ? the cat spoke with behind the woman
# Guess What ? the cat spoke with behind the dog
# Guess What ? the cat spoke with behind the bird
# Guess What ? the cat spoke with behind the cat
# Guess What ? the cat spoke with behind the girl
# Guess What ? the cat spoke with behind the boy
# Guess What ? the cat spoke with behind a man
# Guess What ? the cat spoke with behind a woman
# Guess What ? the cat spoke with behind a dog
# Guess What ? the cat spoke with behind a bird
# Guess What ? the cat spoke with behind a cat
# Guess What ? the cat spoke with behind a girl
# Guess What ? the cat spoke with behind a boy
# Guess What ? the cat spoke with in front of the man
# Guess What ? the cat spoke with in front of the woman
# Guess What ? the cat spoke with in front of the dog
# Guess What ? the cat spoke with in front of the bird
# Guess What ? the cat spoke with in front of the cat
# Guess What ? the cat spoke with in front of the girl
# Guess What ? the cat spoke with in front of the boy
# Guess What ? the cat spoke with in front of a man
# Guess What ? the cat spoke with in front of a woman
# Guess What ? the cat spoke with in front of a dog
# Guess What ? the cat spoke with in front of a bird
# Guess What ? the cat spoke with in front of a cat
# Guess What ? the cat spoke with in front of a girl
# Guess What ? the cat spoke with in front of a boy
# Guess What ? the girl slept
# Guess What ? the girl observed the man
# Guess What ? the girl observed the woman
# Guess What ? the girl observed the dog
# Guess What ? the girl observed the bird
# Guess What ? the girl observed the cat
# Guess What ? the girl observed the girl
# Guess What ? the girl observed the boy
# Guess What ? the girl observed a man
# Guess What ? the girl observed a woman
# Guess What ? the girl observed a dog
# Guess What ? the girl observed a bird
# Guess What ? the girl observed a cat
# Guess What ? the girl observed a girl
# Guess What ? the girl observed a boy
# Guess What ? the girl walked
# Guess What ? the girl ran
# Guess What ? the girl jumped
# Guess What ? the girl spoke with over the man
# Guess What ? the girl spoke with over the woman
# Guess What ? the girl spoke with over the dog
# Guess What ? the girl spoke with over the bird
# Guess What ? the girl spoke with over the cat
# Guess What ? the girl spoke with over the girl
# Guess What ? the girl spoke with over the boy
# Guess What ? the girl spoke with over a man
# Guess What ? the girl spoke with over a woman
# Guess What ? the girl spoke with over a dog
# Guess What ? the girl spoke with over a bird
# Guess What ? the girl spoke with over a cat
# Guess What ? the girl spoke with over a girl
# Guess What ? the girl spoke with over a boy
# Guess What ? the girl spoke with with the man
# Guess What ? the girl spoke with with the woman
# Guess What ? the girl spoke with with the dog
# Guess What ? the girl spoke with with the bird
# Guess What ? the girl spoke with with the cat
# Guess What ? the girl spoke with with the girl
# Guess What ? the girl spoke with with the boy
# Guess What ? the girl spoke with with a man
# Guess What ? the girl spoke with with a woman
# Guess What ? the girl spoke with with a dog
# Guess What ? the girl spoke with with a bird
# Guess What ? the girl spoke with with a cat
# Guess What ? the girl spoke with with a girl
# Guess What ? the girl spoke with with a boy
# Guess What ? the girl spoke with around the man
# Guess What ? the girl spoke with around the woman
# Guess What ? the girl spoke with around the dog
# Guess What ? the girl spoke with around the bird
# Guess What ? the girl spoke with around the cat
# Guess What ? the girl spoke with around the girl
# Guess What ? the girl spoke with around the boy
# Guess What ? the girl spoke with around a man
# Guess What ? the girl spoke with around a woman
# Guess What ? the girl spoke with around a dog
# Guess What ? the girl spoke with around a bird
# Guess What ? the girl spoke with around a cat
# Guess What ? the girl spoke with around a girl
# Guess What ? the girl spoke with around a boy
# Guess What ? the girl spoke with next to the man
# Guess What ? the girl spoke with next to the woman
# Guess What ? the girl spoke with next to the dog
# Guess What ? the girl spoke with next to the bird
# Guess What ? the girl spoke with next to the cat
# Guess What ? the girl spoke with next to the girl
# Guess What ? the girl spoke with next to the boy
# Guess What ? the girl spoke with next to a man
# Guess What ? the girl spoke with next to a woman
# Guess What ? the girl spoke with next to a dog
# Guess What ? the girl spoke with next to a bird
# Guess What ? the girl spoke with next to a cat
# Guess What ? the girl spoke with next to a girl
# Guess What ? the girl spoke with next to a boy
# Guess What ? the girl spoke with behind the man
# Guess What ? the girl spoke with behind the woman
# Guess What ? the girl spoke with behind the dog
# Guess What ? the girl spoke with behind the bird
# Guess What ? the girl spoke with behind the cat
# Guess What ? the girl spoke with behind the girl
# Guess What ? the girl spoke with behind the boy
# Guess What ? the girl spoke with behind a man
# Guess What ? the girl spoke with behind a woman
# Guess What ? the girl spoke with behind a dog
# Guess What ? the girl spoke with behind a bird
# Guess What ? the girl spoke with behind a cat
# Guess What ? the girl spoke with behind a girl
# Guess What ? the girl spoke with behind a boy
# Guess What ? the girl spoke with in front of the man
# Guess What ? the girl spoke with in front of the woman
# Guess What ? the girl spoke with in front of the dog
# Guess What ? the girl spoke with in front of the bird
# Guess What ? the girl spoke with in front of the cat
# Guess What ? the girl spoke with in front of the girl
# Guess What ? the girl spoke with in front of the boy
# Guess What ? the girl spoke with in front of a man
# Guess What ? the girl spoke with in front of a woman
# Guess What ? the girl spoke with in front of a dog
# Guess What ? the girl spoke with in front of a bird
# Guess What ? the girl spoke with in front of a cat
# Guess What ? the girl spoke with in front of a girl
# Guess What ? the girl spoke with in front of a boy
# Guess What ? the boy slept
# Guess What ? the boy observed the man
# Guess What ? the boy observed the woman
# Guess What ? the boy observed the dog
# Guess What ? the boy observed the bird
# Guess What ? the boy observed the cat
# Guess What ? the boy observed the girl
# Guess What ? the boy observed the boy
# Guess What ? the boy observed a man
# Guess What ? the boy observed a woman
# Guess What ? the boy observed a dog
# Guess What ? the boy observed a bird
# Guess What ? the boy observed a cat
# Guess What ? the boy observed a girl
# Guess What ? the boy observed a boy
# Guess What ? the boy walked
# Guess What ? the boy ran
# Guess What ? the boy jumped
# Guess What ? the boy spoke with over the man
# Guess What ? the boy spoke with over the woman
# Guess What ? the boy spoke with over the dog
# Guess What ? the boy spoke with over the bird
# Guess What ? the boy spoke with over the cat
# Guess What ? the boy spoke with over the girl
# Guess What ? the boy spoke with over the boy
# Guess What ? the boy spoke with over a man
# Guess What ? the boy spoke with over a woman
# Guess What ? the boy spoke with over a dog
# Guess What ? the boy spoke with over a bird
# Guess What ? the boy spoke with over a cat
# Guess What ? the boy spoke with over a girl
# Guess What ? the boy spoke with over a boy
# Guess What ? the boy spoke with with the man
# Guess What ? the boy spoke with with the woman
# Guess What ? the boy spoke with with the dog
# Guess What ? the boy spoke with with the bird
# Guess What ? the boy spoke with with the cat
# Guess What ? the boy spoke with with the girl
# Guess What ? the boy spoke with with the boy
# Guess What ? the boy spoke with with a man
# Guess What ? the boy spoke with with a woman
# Guess What ? the boy spoke with with a dog
# Guess What ? the boy spoke with with a bird
# Guess What ? the boy spoke with with a cat
# Guess What ? the boy spoke with with a girl
# Guess What ? the boy spoke with with a boy
# Guess What ? the boy spoke with around the man
# Guess What ? the boy spoke with around the woman
# Guess What ? the boy spoke with around the dog
# Guess What ? the boy spoke with around the bird
# Guess What ? the boy spoke with around the cat
# Guess What ? the boy spoke with around the girl
# Guess What ? the boy spoke with around the boy
# Guess What ? the boy spoke with around a man
# Guess What ? the boy spoke with around a woman
# Guess What ? the boy spoke with around a dog
# Guess What ? the boy spoke with around a bird
# Guess What ? the boy spoke with around a cat
# Guess What ? the boy spoke with around a girl
# Guess What ? the boy spoke with around a boy
# Guess What ? the boy spoke with next to the man
# Guess What ? the boy spoke with next to the woman
# Guess What ? the boy spoke with next to the dog
# Guess What ? the boy spoke with next to the bird
# Guess What ? the boy spoke with next to the cat
# Guess What ? the boy spoke with next to the girl
# Guess What ? the boy spoke with next to the boy
# Guess What ? the boy spoke with next to a man
# Guess What ? the boy spoke with next to a woman
# Guess What ? the boy spoke with next to a dog
# Guess What ? the boy spoke with next to a bird
# Guess What ? the boy spoke with next to a cat
# Guess What ? the boy spoke with next to a girl
# Guess What ? the boy spoke with next to a boy
# Guess What ? the boy spoke with behind the man
# Guess What ? the boy spoke with behind the woman
# Guess What ? the boy spoke with behind the dog
# Guess What ? the boy spoke with behind the bird
# Guess What ? the boy spoke with behind the cat
# Guess What ? the boy spoke with behind the girl
# Guess What ? the boy spoke with behind the boy
# Guess What ? the boy spoke with behind a man
# Guess What ? the boy spoke with behind a woman
# Guess What ? the boy spoke with behind a dog
# Guess What ? the boy spoke with behind a bird
# Guess What ? the boy spoke with behind a cat
# Guess What ? the boy spoke with behind a girl
# Guess What ? the boy spoke with behind a boy
# Guess What ? the boy spoke with in front of the man
# Guess What ? the boy spoke with in front of the woman
# Guess What ? the boy spoke with in front of the dog
# Guess What ? the boy spoke with in front of the bird
# Guess What ? the boy spoke with in front of the cat
# Guess What ? the boy spoke with in front of the girl
# Guess What ? the boy spoke with in front of the boy
# Guess What ? the boy spoke with in front of a man
# Guess What ? the boy spoke with in front of a woman
# Guess What ? the boy spoke with in front of a dog
# Guess What ? the boy spoke with in front of a bird
# Guess What ? the boy spoke with in front of a cat
# Guess What ? the boy spoke with in front of a girl
# Guess What ? the boy spoke with in front of a boy
# Guess What ? a man slept
# Guess What ? a man observed the man
# Guess What ? a man observed the woman
# Guess What ? a man observed the dog
# Guess What ? a man observed the bird
# Guess What ? a man observed the cat
# Guess What ? a man observed the girl
# Guess What ? a man observed the boy
# Guess What ? a man observed a man
# Guess What ? a man observed a woman
# Guess What ? a man observed a dog
# Guess What ? a man observed a bird
# Guess What ? a man observed a cat
# Guess What ? a man observed a girl
# Guess What ? a man observed a boy
# Guess What ? a man walked
# Guess What ? a man ran
# Guess What ? a man jumped
# Guess What ? a man spoke with over the man
# Guess What ? a man spoke with over the woman
# Guess What ? a man spoke with over the dog
# Guess What ? a man spoke with over the bird
# Guess What ? a man spoke with over the cat
# Guess What ? a man spoke with over the girl
# Guess What ? a man spoke with over the boy
# Guess What ? a man spoke with over a man
# Guess What ? a man spoke with over a woman
# Guess What ? a man spoke with over a dog
# Guess What ? a man spoke with over a bird
# Guess What ? a man spoke with over a cat
# Guess What ? a man spoke with over a girl
# Guess What ? a man spoke with over a boy
# Guess What ? a man spoke with with the man
# Guess What ? a man spoke with with the woman
# Guess What ? a man spoke with with the dog
# Guess What ? a man spoke with with the bird
# Guess What ? a man spoke with with the cat
# Guess What ? a man spoke with with the girl
# Guess What ? a man spoke with with the boy
# Guess What ? a man spoke with with a man
# Guess What ? a man spoke with with a woman
# Guess What ? a man spoke with with a dog
# Guess What ? a man spoke with with a bird
# Guess What ? a man spoke with with a cat
# Guess What ? a man spoke with with a girl
# Guess What ? a man spoke with with a boy
# Guess What ? a man spoke with around the man
# Guess What ? a man spoke with around the woman
# Guess What ? a man spoke with around the dog
# Guess What ? a man spoke with around the bird
# Guess What ? a man spoke with around the cat
# Guess What ? a man spoke with around the girl
# Guess What ? a man spoke with around the boy
# Guess What ? a man spoke with around a man
# Guess What ? a man spoke with around a woman
# Guess What ? a man spoke with around a dog
# Guess What ? a man spoke with around a bird
# Guess What ? a man spoke with around a cat
# Guess What ? a man spoke with around a girl
# Guess What ? a man spoke with around a boy
# Guess What ? a man spoke with next to the man
# Guess What ? a man spoke with next to the woman
# Guess What ? a man spoke with next to the dog
# Guess What ? a man spoke with next to the bird
# Guess What ? a man spoke with next to the cat
# Guess What ? a man spoke with next to the girl
# Guess What ? a man spoke with next to the boy
# Guess What ? a man spoke with next to a man
# Guess What ? a man spoke with next to a woman
# Guess What ? a man spoke with next to a dog
# Guess What ? a man spoke with next to a bird
# Guess What ? a man spoke with next to a cat
# Guess What ? a man spoke with next to a girl
# Guess What ? a man spoke with next to a boy
# Guess What ? a man spoke with behind the man
# Guess What ? a man spoke with behind the woman
# Guess What ? a man spoke with behind the dog
# Guess What ? a man spoke with behind the bird
# Guess What ? a man spoke with behind the cat
# Guess What ? a man spoke with behind the girl
# Guess What ? a man spoke with behind the boy
# Guess What ? a man spoke with behind a man
# Guess What ? a man spoke with behind a woman
# Guess What ? a man spoke with behind a dog
# Guess What ? a man spoke with behind a bird
# Guess What ? a man spoke with behind a cat
# Guess What ? a man spoke with behind a girl
# Guess What ? a man spoke with behind a boy
# Guess What ? a man spoke with in front of the man
# Guess What ? a man spoke with in front of the woman
# Guess What ? a man spoke with in front of the dog
# Guess What ? a man spoke with in front of the bird
# Guess What ? a man spoke with in front of the cat
# Guess What ? a man spoke with in front of the girl
# Guess What ? a man spoke with in front of the boy
# Guess What ? a man spoke with in front of a man
# Guess What ? a man spoke with in front of a woman
# Guess What ? a man spoke with in front of a dog
# Guess What ? a man spoke with in front of a bird
# Guess What ? a man spoke with in front of a cat
# Guess What ? a man spoke with in front of a girl
# Guess What ? a man spoke with in front of a boy
# Guess What ? a woman slept
# Guess What ? a woman observed the man
# Guess What ? a woman observed the woman
# Guess What ? a woman observed the dog
# Guess What ? a woman observed the bird
# Guess What ? a woman observed the cat
# Guess What ? a woman observed the girl
# Guess What ? a woman observed the boy
# Guess What ? a woman observed a man
# Guess What ? a woman observed a woman
# Guess What ? a woman observed a dog
# Guess What ? a woman observed a bird
# Guess What ? a woman observed a cat
# Guess What ? a woman observed a girl
# Guess What ? a woman observed a boy
# Guess What ? a woman walked
# Guess What ? a woman ran
# Guess What ? a woman jumped
# Guess What ? a woman spoke with over the man
# Guess What ? a woman spoke with over the woman
# Guess What ? a woman spoke with over the dog
# Guess What ? a woman spoke with over the bird
# Guess What ? a woman spoke with over the cat
# Guess What ? a woman spoke with over the girl
# Guess What ? a woman spoke with over the boy
# Guess What ? a woman spoke with over a man
# Guess What ? a woman spoke with over a woman
# Guess What ? a woman spoke with over a dog
# Guess What ? a woman spoke with over a bird
# Guess What ? a woman spoke with over a cat
# Guess What ? a woman spoke with over a girl
# Guess What ? a woman spoke with over a boy
# Guess What ? a woman spoke with with the man
# Guess What ? a woman spoke with with the woman
# Guess What ? a woman spoke with with the dog
# Guess What ? a woman spoke with with the bird
# Guess What ? a woman spoke with with the cat
# Guess What ? a woman spoke with with the girl
# Guess What ? a woman spoke with with the boy
# Guess What ? a woman spoke with with a man
# Guess What ? a woman spoke with with a woman
# Guess What ? a woman spoke with with a dog
# Guess What ? a woman spoke with with a bird
# Guess What ? a woman spoke with with a cat
# Guess What ? a woman spoke with with a girl
# Guess What ? a woman spoke with with a boy
# Guess What ? a woman spoke with around the man
# Guess What ? a woman spoke with around the woman
# Guess What ? a woman spoke with around the dog
# Guess What ? a woman spoke with around the bird
# Guess What ? a woman spoke with around the cat
# Guess What ? a woman spoke with around the girl
# Guess What ? a woman spoke with around the boy
# Guess What ? a woman spoke with around a man
# Guess What ? a woman spoke with around a woman
# Guess What ? a woman spoke with around a dog
# Guess What ? a woman spoke with around a bird
# Guess What ? a woman spoke with around a cat
# Guess What ? a woman spoke with around a girl
# Guess What ? a woman spoke with around a boy
# Guess What ? a woman spoke with next to the man
# Guess What ? a woman spoke with next to the woman
# Guess What ? a woman spoke with next to the dog
# Guess What ? a woman spoke with next to the bird
# Guess What ? a woman spoke with next to the cat
# Guess What ? a woman spoke with next to the girl
# Guess What ? a woman spoke with next to the boy
# Guess What ? a woman spoke with next to a man
# Guess What ? a woman spoke with next to a woman
# Guess What ? a woman spoke with next to a dog
# Guess What ? a woman spoke with next to a bird
# Guess What ? a woman spoke with next to a cat
# Guess What ? a woman spoke with next to a girl
# Guess What ? a woman spoke with next to a boy
# Guess What ? a woman spoke with behind the man
# Guess What ? a woman spoke with behind the woman
# Guess What ? a woman spoke with behind the dog
# Guess What ? a woman spoke with behind the bird
# Guess What ? a woman spoke with behind the cat
# Guess What ? a woman spoke with behind the girl
# Guess What ? a woman spoke with behind the boy
# Guess What ? a woman spoke with behind a man
# Guess What ? a woman spoke with behind a woman
# Guess What ? a woman spoke with behind a dog
# Guess What ? a woman spoke with behind a bird
# Guess What ? a woman spoke with behind a cat
# Guess What ? a woman spoke with behind a girl
# Guess What ? a woman spoke with behind a boy
# Guess What ? a woman spoke with in front of the man
# Guess What ? a woman spoke with in front of the woman
# Guess What ? a woman spoke with in front of the dog
# Guess What ? a woman spoke with in front of the bird
# Guess What ? a woman spoke with in front of the cat
# Guess What ? a woman spoke with in front of the girl
# Guess What ? a woman spoke with in front of the boy
# Guess What ? a woman spoke with in front of a man
# Guess What ? a woman spoke with in front of a woman
# Guess What ? a woman spoke with in front of a dog
# Guess What ? a woman spoke with in front of a bird
# Guess What ? a woman spoke with in front of a cat
# Guess What ? a woman spoke with in front of a girl
# Guess What ? a woman spoke with in front of a boy
# Guess What ? a dog slept
# Guess What ? a dog observed the man
# Guess What ? a dog observed the woman
# Guess What ? a dog observed the dog
# Guess What ? a dog observed the bird
# Guess What ? a dog observed the cat
# Guess What ? a dog observed the girl
# Guess What ? a dog observed the boy
# Guess What ? a dog observed a man
# Guess What ? a dog observed a woman
# Guess What ? a dog observed a dog
# Guess What ? a dog observed a bird
# Guess What ? a dog observed a cat
# Guess What ? a dog observed a girl
# Guess What ? a dog observed a boy
# Guess What ? a dog walked
# Guess What ? a dog ran
# Guess What ? a dog jumped
# Guess What ? a dog spoke with over the man
# Guess What ? a dog spoke with over the woman
# Guess What ? a dog spoke with over the dog
# Guess What ? a dog spoke with over the bird
# Guess What ? a dog spoke with over the cat
# Guess What ? a dog spoke with over the girl
# Guess What ? a dog spoke with over the boy
# Guess What ? a dog spoke with over a man
# Guess What ? a dog spoke with over a woman
# Guess What ? a dog spoke with over a dog
# Guess What ? a dog spoke with over a bird
# Guess What ? a dog spoke with over a cat
# Guess What ? a dog spoke with over a girl
# Guess What ? a dog spoke with over a boy
# Guess What ? a dog spoke with with the man
# Guess What ? a dog spoke with with the woman
# Guess What ? a dog spoke with with the dog
# Guess What ? a dog spoke with with the bird
# Guess What ? a dog spoke with with the cat
# Guess What ? a dog spoke with with the girl
# Guess What ? a dog spoke with with the boy
# Guess What ? a dog spoke with with a man
# Guess What ? a dog spoke with with a woman
# Guess What ? a dog spoke with with a dog
# Guess What ? a dog spoke with with a bird
# Guess What ? a dog spoke with with a cat
# Guess What ? a dog spoke with with a girl
# Guess What ? a dog spoke with with a boy
# Guess What ? a dog spoke with around the man
# Guess What ? a dog spoke with around the woman
# Guess What ? a dog spoke with around the dog
# Guess What ? a dog spoke with around the bird
# Guess What ? a dog spoke with around the cat
# Guess What ? a dog spoke with around the girl
# Guess What ? a dog spoke with around the boy
# Guess What ? a dog spoke with around a man
# Guess What ? a dog spoke with around a woman
# Guess What ? a dog spoke with around a dog
# Guess What ? a dog spoke with around a bird
# Guess What ? a dog spoke with around a cat
# Guess What ? a dog spoke with around a girl
# Guess What ? a dog spoke with around a boy
# Guess What ? a dog spoke with next to the man
# Guess What ? a dog spoke with next to the woman
# Guess What ? a dog spoke with next to the dog
# Guess What ? a dog spoke with next to the bird
# Guess What ? a dog spoke with next to the cat
# Guess What ? a dog spoke with next to the girl
# Guess What ? a dog spoke with next to the boy
# Guess What ? a dog spoke with next to a man
# Guess What ? a dog spoke with next to a woman
# Guess What ? a dog spoke with next to a dog
# Guess What ? a dog spoke with next to a bird
# Guess What ? a dog spoke with next to a cat
# Guess What ? a dog spoke with next to a girl
# Guess What ? a dog spoke with next to a boy
# Guess What ? a dog spoke with behind the man
# Guess What ? a dog spoke with behind the woman
# Guess What ? a dog spoke with behind the dog
# Guess What ? a dog spoke with behind the bird
# Guess What ? a dog spoke with behind the cat
# Guess What ? a dog spoke with behind the girl
# Guess What ? a dog spoke with behind the boy
# Guess What ? a dog spoke with behind a man
# Guess What ? a dog spoke with behind a woman
# Guess What ? a dog spoke with behind a dog
# Guess What ? a dog spoke with behind a bird
# Guess What ? a dog spoke with behind a cat
# Guess What ? a dog spoke with behind a girl
# Guess What ? a dog spoke with behind a boy
# Guess What ? a dog spoke with in front of the man
# Guess What ? a dog spoke with in front of the woman
# Guess What ? a dog spoke with in front of the dog
# Guess What ? a dog spoke with in front of the bird
# Guess What ? a dog spoke with in front of the cat
# Guess What ? a dog spoke with in front of the girl
# Guess What ? a dog spoke with in front of the boy
# Guess What ? a dog spoke with in front of a man
# Guess What ? a dog spoke with in front of a woman
# Guess What ? a dog spoke with in front of a dog
# Guess What ? a dog spoke with in front of a bird
# Guess What ? a dog spoke with in front of a cat
# Guess What ? a dog spoke with in front of a girl
# Guess What ? a dog spoke with in front of a boy
# Guess What ? a bird slept
# Guess What ? a bird observed the man
# Guess What ? a bird observed the woman
# Guess What ? a bird observed the dog
# Guess What ? a bird observed the bird
# Guess What ? a bird observed the cat
# Guess What ? a bird observed the girl
# Guess What ? a bird observed the boy
# Guess What ? a bird observed a man
# Guess What ? a bird observed a woman
# Guess What ? a bird observed a dog
# Guess What ? a bird observed a bird
# Guess What ? a bird observed a cat
# Guess What ? a bird observed a girl
# Guess What ? a bird observed a boy
# Guess What ? a bird walked
# Guess What ? a bird ran
# Guess What ? a bird jumped
# Guess What ? a bird spoke with over the man
# Guess What ? a bird spoke with over the woman
# Guess What ? a bird spoke with over the dog
# Guess What ? a bird spoke with over the bird
# Guess What ? a bird spoke with over the cat
# Guess What ? a bird spoke with over the girl
# Guess What ? a bird spoke with over the boy
# Guess What ? a bird spoke with over a man
# Guess What ? a bird spoke with over a woman
# Guess What ? a bird spoke with over a dog
# Guess What ? a bird spoke with over a bird
# Guess What ? a bird spoke with over a cat
# Guess What ? a bird spoke with over a girl
# Guess What ? a bird spoke with over a boy
# Guess What ? a bird spoke with with the man
# Guess What ? a bird spoke with with the woman
# Guess What ? a bird spoke with with the dog
# Guess What ? a bird spoke with with the bird
# Guess What ? a bird spoke with with the cat
# Guess What ? a bird spoke with with the girl
# Guess What ? a bird spoke with with the boy
# Guess What ? a bird spoke with with a man
# Guess What ? a bird spoke with with a woman
# Guess What ? a bird spoke with with a dog
# Guess What ? a bird spoke with with a bird
# Guess What ? a bird spoke with with a cat
# Guess What ? a bird spoke with with a girl
# Guess What ? a bird spoke with with a boy
# Guess What ? a bird spoke with around the man
# Guess What ? a bird spoke with around the woman
# Guess What ? a bird spoke with around the dog
# Guess What ? a bird spoke with around the bird
# Guess What ? a bird spoke with around the cat
# Guess What ? a bird spoke with around the girl
# Guess What ? a bird spoke with around the boy
# Guess What ? a bird spoke with around a man
# Guess What ? a bird spoke with around a woman
# ...
# Yesterday a bird observed a boy
# Yesterday a bird walked
# Yesterday a bird ran
# Yesterday a bird jumped
# Yesterday a bird spoke with over the man
# Yesterday a bird spoke with over the woman
# Yesterday a bird spoke with over the dog
# Yesterday a bird spoke with over the bird
# Yesterday a bird spoke with over the cat
# Yesterday a bird spoke with over the girl
# Yesterday a bird spoke with over the boy
# Yesterday a bird spoke with over a man
# Yesterday a bird spoke with over a woman
# Yesterday a bird spoke with over a dog
# Yesterday a bird spoke with over a bird
# Yesterday a bird spoke with over a cat
# Yesterday a bird spoke with over a girl
# Yesterday a bird spoke with over a boy
# Yesterday a bird spoke with with the man
# Yesterday a bird spoke with with the woman
# Yesterday a bird spoke with with the dog
# Yesterday a bird spoke with with the bird
# Yesterday a bird spoke with with the cat
# Yesterday a bird spoke with with the girl
# Yesterday a bird spoke with with the boy
# Yesterday a bird spoke with with a man
# Yesterday a bird spoke with with a woman
# Yesterday a bird spoke with with a dog
# Yesterday a bird spoke with with a bird
# Yesterday a bird spoke with with a cat
# Yesterday a bird spoke with with a girl
# Yesterday a bird spoke with with a boy
# Yesterday a bird spoke with around the man
# Yesterday a bird spoke with around the woman
# Yesterday a bird spoke with around the dog
# Yesterday a bird spoke with around the bird
# Yesterday a bird spoke with around the cat
# Yesterday a bird spoke with around the girl
# Yesterday a bird spoke with around the boy
# Yesterday a bird spoke with around a man
# Yesterday a bird spoke with around a woman
# Yesterday a bird spoke with around a dog
# Yesterday a bird spoke with around a bird
# Yesterday a bird spoke with around a cat
# Yesterday a bird spoke with around a girl
# Yesterday a bird spoke with around a boy
# Yesterday a bird spoke with next to the man
# Yesterday a bird spoke with next to the woman
# Yesterday a bird spoke with next to the dog
# Yesterday a bird spoke with next to the bird
# Yesterday a bird spoke with next to the cat
# Yesterday a bird spoke with next to the girl
# Yesterday a bird spoke with next to the boy
# Yesterday a bird spoke with next to a man
# Yesterday a bird spoke with next to a woman
# Yesterday a bird spoke with next to a dog
# Yesterday a bird spoke with next to a bird
# Yesterday a bird spoke with next to a cat
# Yesterday a bird spoke with next to a girl
# Yesterday a bird spoke with next to a boy
# Yesterday a bird spoke with behind the man
# Yesterday a bird spoke with behind the woman
# Yesterday a bird spoke with behind the dog
# Yesterday a bird spoke with behind the bird
# Yesterday a bird spoke with behind the cat
# Yesterday a bird spoke with behind the girl
# Yesterday a bird spoke with behind the boy
# Yesterday a bird spoke with behind a man
# Yesterday a bird spoke with behind a woman
# Yesterday a bird spoke with behind a dog
# Yesterday a bird spoke with behind a bird
# Yesterday a bird spoke with behind a cat
# Yesterday a bird spoke with behind a girl
# Yesterday a bird spoke with behind a boy
# Yesterday a bird spoke with in front of the man
# Yesterday a bird spoke with in front of the woman
# Yesterday a bird spoke with in front of the dog
# Yesterday a bird spoke with in front of the bird
# Yesterday a bird spoke with in front of the cat
# Yesterday a bird spoke with in front of the girl
# Yesterday a bird spoke with in front of the boy
# Yesterday a bird spoke with in front of a man
# Yesterday a bird spoke with in front of a woman
# Yesterday a bird spoke with in front of a dog
# Yesterday a bird spoke with in front of a bird
# Yesterday a bird spoke with in front of a cat
# Yesterday a bird spoke with in front of a girl
# Yesterday a bird spoke with in front of a boy
# Yesterday a cat slept
# Yesterday a cat observed the man
# Yesterday a cat observed the woman
# Yesterday a cat observed the dog
# Yesterday a cat observed the bird
# Yesterday a cat observed the cat
# Yesterday a cat observed the girl
# Yesterday a cat observed the boy
# Yesterday a cat observed a man
# Yesterday a cat observed a woman
# Yesterday a cat observed a dog
# Yesterday a cat observed a bird
# Yesterday a cat observed a cat
# Yesterday a cat observed a girl
# Yesterday a cat observed a boy
# Yesterday a cat walked
# Yesterday a cat ran
# Yesterday a cat jumped
# Yesterday a cat spoke with over the man
# Yesterday a cat spoke with over the woman
# Yesterday a cat spoke with over the dog
# Yesterday a cat spoke with over the bird
# Yesterday a cat spoke with over the cat
# Yesterday a cat spoke with over the girl
# Yesterday a boy spoke with behind the dog
# Yesterday a boy spoke with behind the bird
# Yesterday a boy spoke with behind the cat
# Yesterday a boy spoke with behind the girl
# Yesterday a boy spoke with behind the boy
# Yesterday a boy spoke with behind a man
# Yesterday a boy spoke with behind a woman
# Yesterday a boy spoke with behind a dog
# Yesterday a boy spoke with behind a bird
# Yesterday a boy spoke with behind a cat
# Yesterday a boy spoke with behind a girl
# Yesterday a boy spoke with behind a boy
# Yesterday a boy spoke with in front of the man
# Yesterday a boy spoke with in front of the woman
# Yesterday a boy spoke with in front of the dog
# Yesterday a boy spoke with in front of the bird
# Yesterday a boy spoke with in front of the cat
# Yesterday a boy spoke with in front of the girl
# Yesterday a boy spoke with in front of the boy
# Yesterday a boy spoke with in front of a man
# Yesterday a boy spoke with in front of a woman
# Yesterday a boy spoke with in front of a dog
# Yesterday a boy spoke with in front of a bird
# Yesterday a boy spoke with in front of a cat
# Yesterday a boy spoke with in front of a girl
# Yesterday a boy spoke with in front of a boy

# %%
# %%writefile Nltktest
#     S -> NP VP
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept' | 'observed' NP | 'walked' | 'ran' | 'jumped' | 'spoke with' PP
#     Det -> 'the' | 'a'
#     N -> 'man' | 'woman' | 'dog' |'bird' | 'cat' | 'girl' | 'boy'
#     P -> 'over' | 'with' | 'around' | 'next to' | 'behind' | 'in front of'
# Out:
# Overwriting Nltktest

# %%
# %%writefile Nltktest
#     S -> NP VP
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept' | 'observed' NP | 'walked' | 'ran' | 'jumped' | 'played' | 'spoke with' PP
#     Det -> 'some' | 'several' | 'many' | ' a few' | 'a crowd of'
#     N -> 'men' | 'women' | 'dogs' |'birds' | 'cats' | 'girls' | 'boys' | 'old men' | 'old women'
#     P -> 'over' | 'with' | 'around' | 'next to' | 'behind' | 'in front of'
# Out:
# Overwriting Nltktest

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG
F = open('Nltktest','r') 
grammar = CFG.fromstring(F)
print(grammar)
# Out:
# Grammar with 30 productions (start state = S)
#     S -> NP VP
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept'
#     VP -> 'observed' NP
#     VP -> 'walked'
#     VP -> 'ran'
#     VP -> 'jumped'
#     VP -> 'played'
#     VP -> 'spoke with' PP
#     Det -> 'some'
#     Det -> 'several'
#     Det -> 'many'
#     Det -> ' a few'
#     Det -> 'a crowd of'
#     N -> 'men'
#     N -> 'women'
#     N -> 'dogs'
#     N -> 'birds'
#     N -> 'cats'
#     N -> 'girls'
#     N -> 'boys'
#     N -> 'old men'
#     N -> 'old women'
#     P -> 'over'
#     P -> 'with'
#     P -> 'around'
#     P -> 'next to'
#     P -> 'behind'
#     P -> 'in front of'

# %%
for sentence in generate(grammar, depth=6):
    print(' '.join(sentence))
# Out:
# some men slept
# some men observed some men
# some men observed some women
# some men observed some dogs
# some men observed some birds
# some men observed some cats
# some men observed some girls
# some men observed some boys
# some men observed some old men
# some men observed some old women
# some men observed several men
# some men observed several women
# some men observed several dogs
# some men observed several birds
# some women spoke with over some dogs
# some women spoke with over some birds
# some women spoke with over some cats
# some women spoke with over some girls
# some women spoke with over some boys
# some women spoke with over some old men
# some women spoke with over some old women
# some women spoke with over several men
# some women spoke with over several women
# some women spoke with over several dogs
# some women spoke with over several birds
# some women spoke with over several cats
# some women spoke with over several girls
# some women spoke with over several boys
# some women spoke with over several old men
# some women spoke with over several old women
# some women spoke with over many men
# some women spoke with over many women
# some women spoke with over many dogs
# some women spoke with over many birds
# some women spoke with over many cats
# some women spoke with over many girls
# some women spoke with over many boys
# some women spoke with over many old men
# some women spoke with over many old women
# some women spoke with over  a few men
# some women spoke with over  a few women
# some women spoke with over  a few dogs
# some women spoke with over  a few birds
# some women spoke with over  a few cats
# some women spoke with over  a few girls
# some women spoke with over  a few boys
# some women spoke with over  a few old men
# some women spoke with over  a few old women
# some women spoke with over a crowd of men
# some women spoke with over a crowd of women
# some women spoke with over a crowd of dogs
# some women spoke with over a crowd of birds
# some women spoke with over a crowd of cats
# some women spoke with over a crowd of girls
# some women spoke with over a crowd of boys
# some women spoke with over a crowd of old men
# some women spoke with over a crowd of old women
# some women spoke with with some men
# some women spoke with with some women
# some women spoke with with some dogs
# some women spoke with with some birds
# some women spoke with with some cats
# some women spoke with with some girls
# some women spoke with with some boys
# some women spoke with with some old men
# some women spoke with with some old women
# some women spoke with with several men
# some women spoke with with several women
# some women spoke with with several dogs
# some women spoke with with several birds
# some women spoke with with several cats
# some women spoke with with several girls
# some women spoke with with several boys
# some women spoke with with several old men
# some women spoke with with several old women
# some women spoke with with many men
# some women spoke with with many women
# some women spoke with with many dogs
# some women spoke with with many birds
# some women spoke with with many cats
# some women spoke with with many girls
# some women spoke with with many boys
# some women spoke with with many old men
# some women spoke with with many old women
# some women spoke with with  a few men
# some women spoke with with  a few women
# some women spoke with with  a few dogs
# some women spoke with with  a few birds
# some women spoke with with  a few cats
# some women spoke with with  a few girls
# some women spoke with with  a few boys
# some women spoke with with  a few old men
# some women spoke with with  a few old women
# some women spoke with with a crowd of men
# some women spoke with with a crowd of women
# some women spoke with with a crowd of dogs
# some women spoke with with a crowd of birds
# some women spoke with with a crowd of cats
# some women spoke with with a crowd of girls
# some women spoke with with a crowd of boys
# some women spoke with with a crowd of old men
# some women spoke with with a crowd of old women
# some women spoke with around some men
# some women spoke with around some women
# some women spoke with around some dogs
# some women spoke with around some birds
# some women spoke with around some cats
# some women spoke with around some girls
# some women spoke with around some boys
# some women spoke with around some old men
# some women spoke with around some old women
# some women spoke with around several men
# some women spoke with around several women
# some women spoke with around several dogs
# some women spoke with around several birds
# some women spoke with around several cats
# some women spoke with around several girls
# some women spoke with around several boys
# some women spoke with around several old men
# some women spoke with around several old women
# some women spoke with around many men
# some women spoke with around many women
# some women spoke with around many dogs
# some women spoke with around many birds
# some women spoke with around many cats
# some women spoke with around many girls
# some women spoke with around many boys
# some women spoke with around many old men
# some women spoke with around many old women
# some women spoke with around  a few men
# some women spoke with around  a few women
# some women spoke with around  a few dogs
# some women spoke with around  a few birds
# some women spoke with around  a few cats
# some women spoke with around  a few girls
# some women spoke with around  a few boys
# some women spoke with around  a few old men
# some women spoke with around  a few old women
# some women spoke with around a crowd of men
# some women spoke with around a crowd of women
# some women spoke with around a crowd of dogs
# some women spoke with around a crowd of birds
# some women spoke with around a crowd of cats
# some women spoke with around a crowd of girls
# some women spoke with around a crowd of boys
# some women spoke with around a crowd of old men
# some women spoke with around a crowd of old women
# some women spoke with next to some men
# some women spoke with next to some women
# some women spoke with next to some dogs
# some women spoke with next to some birds
# some women spoke with next to some cats
# some women spoke with next to some girls
# some women spoke with next to some boys
# some women spoke with next to some old men
# some women spoke with next to some old women
# some women spoke with next to several men
# some women spoke with next to several women
# some women spoke with next to several dogs
# some women spoke with next to several birds
# some women spoke with next to several cats
# some women spoke with next to several girls
# some women spoke with next to several boys
# some women spoke with next to several old men
# some women spoke with next to several old women
# some women spoke with next to many men
# some women spoke with next to many women
# some women spoke with next to many dogs
# some women spoke with next to many birds
# some women spoke with next to many cats
# some women spoke with next to many girls
# some women spoke with next to many boys
# some women spoke with next to many old men
# some women spoke with next to many old women
# some women spoke with next to  a few men
# some women spoke with next to  a few women
# some women spoke with next to  a few dogs
# some women spoke with next to  a few birds
# some women spoke with next to  a few cats
# some women spoke with next to  a few girls
# some women spoke with next to  a few boys
# some women spoke with next to  a few old men
# some women spoke with next to  a few old women
# some women spoke with next to a crowd of men
# some women spoke with next to a crowd of women
# some women spoke with next to a crowd of dogs
# some women spoke with next to a crowd of birds
# some women spoke with next to a crowd of cats
# some women spoke with next to a crowd of girls
# some women spoke with next to a crowd of boys
# some women spoke with next to a crowd of old men
# some women spoke with next to a crowd of old women
# some women spoke with behind some men
# some women spoke with behind some women
# some women spoke with behind some dogs
# some women spoke with behind some birds
# some women spoke with behind some cats
# some women spoke with behind some girls
# some women spoke with behind some boys
# some women spoke with behind some old men
# some women spoke with behind some old women
# some women spoke with behind several men
# some women spoke with behind several women
# some women spoke with behind several dogs
# some women spoke with behind several birds
# some women spoke with behind several cats
# some women spoke with behind several girls
# some women spoke with behind several boys
# some women spoke with behind several old men
# some women spoke with behind several old women
# some women spoke with behind many men
# some women spoke with behind many women
# some women spoke with behind many dogs
# some women spoke with behind many birds
# some women spoke with behind many cats
# some women spoke with behind many girls
# some women spoke with behind many boys
# some women spoke with behind many old men
# some women spoke with behind many old women
# some women spoke with behind  a few men
# some women spoke with behind  a few women
# some women spoke with behind  a few dogs
# some women spoke with behind  a few birds
# some women spoke with behind  a few cats
# some women spoke with behind  a few girls
# some women spoke with behind  a few boys
# some women spoke with behind  a few old men
# some women spoke with behind  a few old women
# some women spoke with behind a crowd of men
# some women spoke with behind a crowd of women
# some women spoke with behind a crowd of dogs
# some women spoke with behind a crowd of birds
# some women spoke with behind a crowd of cats
# some women spoke with behind a crowd of girls
# some women spoke with behind a crowd of boys
# some women spoke with behind a crowd of old men
# some women spoke with behind a crowd of old women
# some women spoke with in front of some men
# some women spoke with in front of some women
# some women spoke with in front of some dogs
# some dogs spoke with over many cats
# some dogs spoke with over many girls
# some dogs spoke with over many boys
# some dogs spoke with over many old men
# some dogs spoke with over many old women
# some dogs spoke with over  a few men
# some dogs spoke with over  a few women
# some dogs spoke with over  a few dogs
# some dogs spoke with over  a few birds
# some dogs spoke with over  a few cats
# some dogs spoke with over  a few girls
# some dogs spoke with over  a few boys
# some dogs spoke with over  a few old men
# some dogs spoke with over  a few old women
# some dogs spoke with over a crowd of men
# some dogs spoke with over a crowd of women
# some dogs spoke with over a crowd of dogs
# some dogs spoke with over a crowd of birds
# some dogs spoke with over a crowd of cats
# some dogs spoke with over a crowd of girls
# some dogs spoke with over a crowd of boys
# some dogs spoke with over a crowd of old men
# some dogs spoke with over a crowd of old women
# some dogs spoke with with some men
# some dogs spoke with with some women
# some dogs spoke with with some dogs
# some dogs spoke with with some birds
# some dogs spoke with with some cats
# some dogs spoke with with some girls
# some dogs spoke with with some boys
# some dogs spoke with with some old men
# some dogs spoke with with some old women
# some dogs spoke with with several men
# some dogs spoke with with several women
# some dogs spoke with with several dogs
# some dogs spoke with with several birds
# some dogs spoke with with several cats
# some dogs spoke with with several girls
# some dogs spoke with with several boys
# some dogs spoke with with several old men
# some dogs spoke with with several old women
# some dogs spoke with with many men
# some dogs spoke with with many women
# some dogs spoke with with many dogs
# some dogs spoke with with many birds
# some dogs spoke with with many cats
# some dogs spoke with with many girls
# some dogs spoke with with many boys
# some dogs spoke with with many old men
# some dogs spoke with with many old women
# some dogs spoke with with  a few men
# some dogs spoke with with  a few women
# some dogs spoke with with  a few dogs
# some dogs spoke with with  a few birds
# some dogs spoke with with  a few cats
# some dogs spoke with with  a few girls
# some dogs spoke with with  a few boys
# some dogs spoke with with  a few old men
# some dogs spoke with with  a few old women
# some dogs spoke with with a crowd of men
# some dogs spoke with with a crowd of women
# some dogs spoke with with a crowd of dogs
# some dogs spoke with with a crowd of birds
# some dogs spoke with with a crowd of cats
# some dogs spoke with with a crowd of girls
# some dogs spoke with with a crowd of boys
# some dogs spoke with with a crowd of old men
# some dogs spoke with with a crowd of old women
# some dogs spoke with around some men
# some dogs spoke with around some women
# some dogs spoke with around some dogs
# some dogs spoke with around some birds
# some dogs spoke with around some cats
# some dogs spoke with around some girls
# some dogs spoke with around some boys
# some dogs spoke with around some old men
# some dogs spoke with around some old women
# some dogs spoke with around several men
# some dogs spoke with around several women
# some dogs spoke with around several dogs
# some dogs spoke with around several birds
# some dogs spoke with around several cats
# some dogs spoke with around several girls
# some dogs spoke with around several boys
# some dogs spoke with around several old men
# some dogs spoke with around several old women
# some dogs spoke with around many men
# some dogs spoke with around many women
# some dogs spoke with around many dogs
# some dogs spoke with around many birds
# some dogs spoke with around many cats
# some dogs spoke with around many girls
# some dogs spoke with around many boys
# some dogs spoke with around many old men
# some dogs spoke with around many old women
# some dogs spoke with around  a few men
# some dogs spoke with around  a few women
# some dogs spoke with around  a few dogs
# some dogs spoke with around  a few birds
# some dogs spoke with around  a few cats
# some dogs spoke with around  a few girls
# some dogs spoke with around  a few boys
# some dogs spoke with around  a few old men
# some dogs spoke with around  a few old women
# some dogs spoke with around a crowd of men
# some dogs spoke with around a crowd of women
# some dogs spoke with around a crowd of dogs
# some dogs spoke with around a crowd of birds
# some dogs spoke with around a crowd of cats
# some dogs spoke with around a crowd of girls
# some dogs spoke with around a crowd of boys
# some dogs spoke with around a crowd of old men
# some dogs spoke with around a crowd of old women
# some dogs spoke with next to some men
# some dogs spoke with next to some women
# some dogs spoke with next to some dogs
# some dogs spoke with next to some birds
# some dogs spoke with next to some cats
# some dogs spoke with next to some girls
# some dogs spoke with next to some boys
# some dogs spoke with next to some old men
# some dogs spoke with next to some old women
# some dogs spoke with next to several men
# some dogs spoke with next to several women
# some dogs spoke with next to several dogs
# some dogs spoke with next to several birds
# some dogs spoke with next to several cats
# some dogs spoke with next to several girls
# some dogs spoke with next to several boys
# some dogs spoke with next to several old men
# some dogs spoke with next to several old women
# some dogs spoke with next to many men
# some dogs spoke with next to many women
# some dogs spoke with next to many dogs
# some dogs spoke with next to many birds
# some dogs spoke with next to many cats
# some dogs spoke with next to many girls
# some dogs spoke with next to many boys
# some dogs spoke with next to many old men
# some dogs spoke with next to many old women
# some dogs spoke with next to  a few men
# some dogs spoke with next to  a few women
# some dogs spoke with next to  a few dogs
# some dogs spoke with next to  a few birds
# some dogs spoke with next to  a few cats
# some dogs spoke with next to  a few girls
# some dogs spoke with next to  a few boys
# some dogs spoke with next to  a few old men
# some dogs spoke with next to  a few old women
# some dogs spoke with next to a crowd of men
# some dogs spoke with next to a crowd of women
# some dogs spoke with next to a crowd of dogs
# some dogs spoke with next to a crowd of birds
# some dogs spoke with next to a crowd of cats
# some dogs spoke with next to a crowd of girls
# some dogs spoke with next to a crowd of boys
# some dogs spoke with next to a crowd of old men
# some dogs spoke with next to a crowd of old women
# some dogs spoke with behind some men
# some dogs spoke with behind some women
# some dogs spoke with behind some dogs
# some dogs spoke with behind some birds
# some dogs spoke with behind some cats
# some dogs spoke with behind some girls
# some dogs spoke with behind some boys
# some dogs spoke with behind some old men
# some dogs spoke with behind some old women
# some dogs spoke with behind several men
# some dogs spoke with behind several women
# some dogs spoke with behind several dogs
# some dogs spoke with behind several birds
# some dogs spoke with behind several cats
# some dogs spoke with behind several girls
# some dogs spoke with behind several boys
# some dogs spoke with behind several old men
# some dogs spoke with behind several old women
# some dogs spoke with behind many men
# some dogs spoke with behind many women
# some dogs spoke with behind many dogs
# some dogs spoke with behind many birds
# some dogs spoke with behind many cats
# some dogs spoke with behind many girls
# some dogs spoke with behind many boys
# some dogs spoke with behind many old men
# some dogs spoke with behind many old women
# some dogs spoke with behind  a few men
# some dogs spoke with behind  a few women
# some dogs spoke with behind  a few dogs
# some dogs spoke with behind  a few birds
# some dogs spoke with behind  a few cats
# some dogs spoke with behind  a few girls
# some dogs spoke with behind  a few boys
# some dogs spoke with behind  a few old men
# some dogs spoke with behind  a few old women
# some dogs spoke with behind a crowd of men
# some dogs spoke with behind a crowd of women
# some birds spoke with over some old men
# some birds spoke with over some old women
# some birds spoke with over several men
# some birds spoke with over several women
# some birds spoke with over several dogs
# some birds spoke with over several birds
# some birds spoke with over several cats
# some birds spoke with over several girls
# some birds spoke with over several boys
# some birds spoke with over several old men
# some birds spoke with over several old women
# some birds spoke with over many men
# some birds spoke with over many women
# some birds spoke with over many dogs
# some birds spoke with over many birds
# some birds spoke with over many cats
# some birds spoke with over many girls
# some birds spoke with over many boys
# some birds spoke with over many old men
# some birds spoke with over many old women
# some birds spoke with over  a few men
# some birds spoke with over  a few women
# some birds spoke with over  a few dogs
# some birds spoke with over  a few birds
# some birds spoke with over  a few cats
# some birds spoke with over  a few girls
# some birds spoke with over  a few boys
# some birds spoke with over  a few old men
# some birds spoke with over  a few old women
# some birds spoke with over a crowd of men
# some birds spoke with over a crowd of women
# some birds spoke with over a crowd of dogs
# some birds spoke with over a crowd of birds
# some birds spoke with over a crowd of cats
# some birds spoke with over a crowd of girls
# some birds spoke with over a crowd of boys
# some birds spoke with over a crowd of old men
# some birds spoke with over a crowd of old women
# some birds spoke with with some men
# some birds spoke with with some women
# some birds spoke with with some dogs
# some birds spoke with with some birds
# some birds spoke with with some cats
# some birds spoke with with some girls
# some birds spoke with with some boys
# some birds spoke with with some old men
# some birds spoke with with some old women
# some birds spoke with with several men
# some birds spoke with with several women
# some birds spoke with with several dogs
# some birds spoke with with several birds
# some birds spoke with with several cats
# some birds spoke with with several girls
# some birds spoke with with several boys
# some birds spoke with with several old men
# some birds spoke with with several old women
# some birds spoke with with many men
# some birds spoke with with many women
# some birds spoke with with many dogs
# some birds spoke with with many birds
# some birds spoke with with many cats
# some birds spoke with with many girls
# some birds spoke with with many boys
# some birds spoke with with many old men
# some birds spoke with with many old women
# some birds spoke with with  a few men
# some birds spoke with with  a few women
# some birds spoke with with  a few dogs
# some birds spoke with with  a few birds
# some birds spoke with with  a few cats
# some birds spoke with with  a few girls
# some birds spoke with with  a few boys
# some birds spoke with with  a few old men
# some birds spoke with with  a few old women
# some birds spoke with with a crowd of men
# some birds spoke with with a crowd of women
# some birds spoke with with a crowd of dogs
# some birds spoke with with a crowd of birds
# some birds spoke with with a crowd of cats
# some birds spoke with with a crowd of girls
# some birds spoke with with a crowd of boys
# some birds spoke with with a crowd of old men
# some birds spoke with with a crowd of old women
# some birds spoke with around some men
# some birds spoke with around some women
# some birds spoke with around some dogs
# some birds spoke with around some birds
# some birds spoke with around some cats
# some birds spoke with around some girls
# some birds spoke with around some boys
# some birds spoke with around some old men
# some birds spoke with around some old women
# some birds spoke with around several men
# some birds spoke with around several women
# some birds spoke with around several dogs
# some birds spoke with around several birds
# some birds spoke with around several cats
# some birds spoke with around several girls
# some birds spoke with around several boys
# some birds spoke with around several old men
# some birds spoke with around several old women
# some birds spoke with around many men
# some birds spoke with around many women
# some birds spoke with around many dogs
# some birds spoke with around many birds
# some birds spoke with around many cats
# some birds spoke with around many girls
# some birds spoke with around many boys
# some birds spoke with around many old men
# some birds spoke with around many old women
# a crowd of old women spoke with in front of several men
# a crowd of old women spoke with in front of several women
# a crowd of old women spoke with in front of several dogs
# a crowd of old women spoke with in front of several birds
# a crowd of old women spoke with in front of several cats
# a crowd of old women spoke with in front of several girls
# a crowd of old women spoke with in front of several boys
# a crowd of old women spoke with in front of several old men
# a crowd of old women spoke with in front of several old women
# a crowd of old women spoke with in front of many men
# a crowd of old women spoke with in front of many women
# a crowd of old women spoke with in front of many dogs
# a crowd of old women spoke with in front of many birds
# a crowd of old women spoke with in front of many cats
# a crowd of old women spoke with in front of many girls
# a crowd of old women spoke with in front of many boys
# a crowd of old women spoke with in front of many old men
# a crowd of old women spoke with in front of many old women
# a crowd of old women spoke with in front of  a few men
# a crowd of old women spoke with in front of  a few women
# a crowd of old women spoke with in front of  a few dogs
# a crowd of old women spoke with in front of  a few birds
# a crowd of old women spoke with in front of  a few cats
# a crowd of old women spoke with in front of  a few girls
# a crowd of old women spoke with in front of  a few boys
# a crowd of old women spoke with in front of  a few old men
# a crowd of old women spoke with in front of  a few old women
# a crowd of old women spoke with in front of a crowd of men
# a crowd of old women spoke with in front of a crowd of women
# a crowd of old women spoke with in front of a crowd of dogs
# a crowd of old women spoke with in front of a crowd of birds
# a crowd of old women spoke with in front of a crowd of cats
# a crowd of old women spoke with in front of a crowd of girls
# a crowd of old women spoke with in front of a crowd of boys
# a crowd of old women spoke with in front of a crowd of old men
# a crowd of old women spoke with in front of a crowd of old women

# %%
# %load testfile.txt
a jumped in front of a cat

# %%
for sentence in generate(grammar, n=10):
    print(' '.join(sentence))
# Out:
# the man slept
# the man observed the man
# the man observed the woman
# the man observed the dog
# the man observed the bird
# the man observed the cat
# the man observed the
# the man observed a man
# the man observed a woman
# the man observed a dog

# %%
for sentence in generate(grammar, depth=6):
    tofile = (' '.join(sentence))
    
    
    file = open('testfile.txt','w') 
 
    file.write(tofile)

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG
grammar = CFG.fromstring(demo_grammar)
print(grammar)
# Out:
# Grammar with 13 productions (start state = S)
#     S -> NP VP
#     NP -> Det N
#     PP -> P NP
#     VP -> 'slept'
#     VP -> 'saw' NP
#     VP -> 'walked' PP
#     Det -> 'the'
#     Det -> 'a'
#     N -> 'man'
#     N -> 'park'
#     N -> 'dog'
#     P -> 'in'
#     P -> 'with'

# %%
# Print sample code and key words
import pandas as pd
import sqlite3
# Read sqlite query results into a pandas DataFrame
# Create a SQL connection to our SQLite database
con = sqlite3.connect("data/sqlite-01.db")

df = pd.read_sql_query("SELECT * from python", con)
# verify that result of SQL query is stored in the dataframe
print(df.head())
con.close()

# %%
import sqlite3
import base64
conn = sqlite3.connect('data/sqlite-01.db')

STerm = raw_input("Keyword")

# You may use an exact searchword or to get full use of the term LIKE search a term in this manner:
# %base6%    This will show base64,because it is LIKE base6   


c = conn.cursor()# Never 
#for row in c.execute('SELECT code FROM python ORDER BY code'):
#for row in c.execute("SELECT code FROM python WHERE keyword=?", ('base64',)):
for row in c.execute("SELECT code FROM python WHERE keyword LIKE ?", (STerm,)):    
    #print(row),"\n-----\n","\n"
    #c.fetchone()[0]    
    print base64.decodestring(row[0])
    #print dat 
        
conn.close()

# %%
import sqlite3
import base64
conn = sqlite3.connect('data/sqlite-01.db')
c = conn.cursor()
# Larger example that inserts many records at a time

a = encodedlistvalue=base64.b64encode(
    """
startshape PIUMA
background { b -.8 sat 1  h -10} 
rule PIUMA {
200 * {y .1 s .9975 r -.1}  ELE {s .04}
100 * {y -.1 s .993 r .2}  ELE {s .04}
}
rule ELE {
EL {x 1.6  r 90 }
EL {x  -1.6  r 90 flip 180 }
}
rule EL{
PEN{}
EL{s .999 r -.103 x .2}
}
rule EL 0.000251 {
EL{flip 180}
}
rule EL 0.002 {
EL2{s .8}
//EL2{flip 0 s .8}
}
rule EL2{
PEN{}
EL2{s .9996 r -.08381 x .2}
}
rule EL2 0.000251 {
EL2{flip 180}
}
rule PEN 3 {
PENNA {b 1}
}
rule PEN{
//PENNA {b -1 z -10}
}
rule PENNA{
CIRCLE{a -.99 s 35 b -1 z -2}
//CIRCLE{a -.998 s 10  z -1}
CIRCLE{a -.7}
}    

""")
#a = 'xxccccccccccxxxxxxx'
b = 'PIUMA.cfdg'

#c.execute("INSERT INTO python VALUES (?, ?)" a, b)
#c.execute("INSERT INTO python VALUES (%s, %s,)", (a, b))
c.execute("INSERT INTO python VALUES (?,?)", (a,b))

conn.commit()
conn.close()

# %% [markdown]
# # GREAT EXAMPLE -- Using Context-Free in Java Script

# %%
# %%writefile cfdg.js
# // A2Z F16
# // Daniel Shiffman
# // http://shiffman.net/a2z
# // https://github.com/shiffman/A2Z-F16
#
# // This is based on Allison Parrish's great RWET examples
# // https://github.com/aparrish/rwet-examples
#
# // A grammar object
# var cfree;
#
# function setup() {
#   // An empty one
#   cfree = new ContextFree();
#
#   // We can add rules manually
#   cfree.addRule('S', ['NP', 'VP']);
#   cfree.addRule('NP', ['The', 'N']);
#   cfree.addRule('VP', ['V', 'the', 'N']);
#
#   cfree.addRule('N', ['cat']);
#   cfree.addRule('N', ['dog']);
#   cfree.addRule('N', ['unicorn']);
#   cfree.addRule('N', ['rainbow']);
#   cfree.addRule('V', ['sees']);
#   cfree.addRule('V', ['chases']);
#   cfree.addRule('V', ['falls in love with']);
#   cfree.addRule('V', ['believes']);
#
#   noCanvas();
#   // A button to generate a new sentence
#   var button = select('#generate');
#   button.mousePressed(generate);
#
#   // A button to clear everything
#   var clear = select('#clear');
#   clear.mousePressed(clearAll);
# }
#
# // Remove everything
# function clearAll() {
#   var elements = selectAll('.text');
#   for (var i = 0; i < elements.length; i++) {
#     elements[i].remove();
#   }
# }
#
# function generate() {
#   // Get an expansion starting with 'S'
#   var expansion = cfree.getExpansion('S');
#   // Make a paragraph
#   var par = createP(expansion);
#   par.class('text');
# }

# %%
# %%writefile index.html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Context Free Grammar Example</title>
#     <script src="js/p5.js" type="text/javascript"></script>
#     <script src="js/p5.dom.js" type="text/javascript"></script>
#     <script src="js/cfdg.js" type="text/javascript"></script>
#     <script src="js/cf.js" type="text/javascript"></script>
# <style>
# body {
# padding: 20px;
# }
# h1{
# text-align:center;
# }
# .text {
# padding: 12px;
# background-color: #EEE;
# }
# p {
# text-align:center;
# }
# </style>
#
# </head>
# <body>
# <h1>Context-Free Grammar as  Javascript</h1>
# <p>This illustrates the ability to use Context-Free via JavaScript</p><br />
# <p><button id = "generate">generate</button> <button id = "clearp">clear</button></p>
# </body>
# </html>

# %% [markdown]
# # START A SERVER TO VIEW THE HTML ABOVE

# %% [markdown]
# ## Server Click " http://localhost:8040/ " After Running Script Below

# %%
import sys
import BaseHTTPServer
from SimpleHTTPServer import SimpleHTTPRequestHandler


HandlerClass = SimpleHTTPRequestHandler
ServerClass  = BaseHTTPServer.HTTPServer
Protocol     = "HTTP/1.0"

port = 8040
server_address = ('127.0.0.1', port)

HandlerClass.protocol_version = Protocol
httpd = ServerClass(server_address, HandlerClass)

sa = httpd.socket.getsockname()
print "Serving HTTP on", sa[0], "port", sa[1], "..."
httpd.serve_forever()
# Out:
# Serving HTTP on 127.0.0.1 port 8040 ...
# 127.0.0.1 - - [20/Jul/2017 19:43:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jul/2017 19:43:12] "GET /js/p5.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jul/2017 19:43:12] "GET /js/p5.dom.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jul/2017 19:43:18] code 404, message File not found
# 127.0.0.1 - - [20/Jul/2017 19:43:18] "GET /js/cfdg.js HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Jul/2017 19:43:18] "GET /js/cf.js HTTP/1.1" 200 -

# %%
# %%writefile js/cf.js
# // A2Z F15
# // Daniel Shiffman
# // https://github.com/shiffman/A2Z-F15
#
# // This is based on Allison Parrish's great RWET examples
# // https://github.com/aparrish/rwet-examples
#
# // Prototype is magic!  By accessing Array.prototype
# // we can augment every single Array object with an new function
#
# // Like python's choice this will return a
# // random element from an array
# Array.prototype.choice = function() {
#   var i = floor(random(this.length));
#   return this[i];
# }
#
# // A grammar with empty rules object
# function ContextFree() {
#   this.rules = {};
# }
#
# // Rules are stored in the rules object
# // the rules themselves are arrays of expansions (which themselves are arrays)
# ContextFree.prototype.addRule = function(rule, expansion) {
#   if (this.rules.hasOwnProperty(rule)) {
#     this.rules[rule].push(expansion);
#   } else {
#     this.rules[rule] = [expansion];
#   }
# }
#
# // This function recursively calls itself
# // over and over until it reaches a terminal
# ContextFree.prototype.expand = function(start, expansion) {
#   if (this.rules.hasOwnProperty(start)) {
#     // Grab one possible expansion
#     var possibilities = this.rules[start];
#     var picked = possibilities.choice();
#
#     // call this method again with the current element of the expansion
#     for (var i = 0; i < picked.length; i++) {
#       this.expand(picked[i], expansion);
#     }
#   // If the rule wasn't found, then it's a terminal
#   // add the String to the array
#   } else {
#     expansion.push(start);
#   }
# }
#
# // Start an expansion
# ContextFree.prototype.getExpansion = function(axiom) {
#   // Start with an empty array
#   var expansion = [];
#   // Call the expand function
#   this.expand(axiom, expansion);
#   // Send back a String (rather than array)
#   return expansion.join(' ');
# }
# Out:
# Writing js/cf.js
